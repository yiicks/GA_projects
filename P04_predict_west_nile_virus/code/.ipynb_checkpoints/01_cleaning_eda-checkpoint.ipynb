# %% [markdown]
# # Project 4: Predict and Manage West Nile Virus
# ---
# <font color='sky blue'><font face='Courier New'><i>
# <b>Mission Brief from the Overlords</b>
# <br>
#     <b>"</b>Welcome to your first week of work at the Disease And Treatment Agency, division of Societal Cures In Epidemiology and New Creative Engineering (DATA-SCIENCE). Time to get to work!
# <br>
# Due to the recent epidemic of West Nile Virus in the Windy City, we've had the Department of Public Health set up a surveillance and control system. We're hoping it will let us learn something from the mosquito population as we collect data over time. Pesticides are a necessary evil in the fight for public health and safety, not to mention expensive! We need to derive an effective plan to deploy pesticides throughout the city, and that is exactly where you come in!<b>"</b></i>
# </font>
# <br><br>
# <i><b>Source</b>: Project 4 README</i>
# ---

# %% [markdown]
# ## Introduction
# **West Nile Virus still plagues citizens in Chicago, Illinois, today.**
#
# To make Chicago homes safer for all, our team of Data Scientists have
#
# - analyzed available data to predict likelihood of incidence of the disease, and
#
# - will present a preliminary cost-benefit analysis to inform health authorities on Zenivex spray-based interventions. (see slides)
#
# ---

# %% [markdown]
# ### Problem Statement
# To combat the West Nile virus epidemic in Chicago, analyze available information provided and predict developing vectors and share cost-benefit analysis with the relevant Health Authorities.

# %% [markdown]
# #### Data
# The Authorities have provided us with 4 datasets:
# 1. [Weather](../datasets/weather.csv),
# 2. [Spray](../datasets/spray.csv),
# 3. [Training](../datasets/train.csv),
# 4. [Test](../datasets/test.csv), and
# 5. Mapping resources.

# %% [markdown]
# ### Organization

# %% [markdown]
# #### Folder Organization
# ```
# |__ code
# |   |__ 01_cleaning_eda.ipynb
# |   |__ 02_maps.ipynb
# |   |__ 03_models.ipynb
# |__ datasets
# |   |__ train.csv
# |   |__ test.csv
# |   |__ weather.csv
# |   |__ spray.csv
# |   |__ mapdata_copyright_openstreetmap_contributors.txt
# |__ images
# |   |__ gif_frames   # image data for GIF 1
# |   |__ gif_frames2  # image data for GIF 2
# |__ P04_group_presentation.pdf
# |__ README.md
# ```

# %% [markdown]
# **Across the Project**
# 1. **Cleaning, Exploratory Visualizations, and Export (Current Notebook)**
# 2. [Maps (Visualizations)](./02_maps.ipynb)
# 3. [Models and Conclusions](./03_models.ipynb)
#
# **Within this Notebook**
# 1. [Data Cleaning: Summary](#Data-Cleaning)
# 1. [Data Cleaning: Import](#Import)
# 1. [Data Cleaning: Functions](#Functions)
# 1. [Data Cleaning: Weather](#Weather)
# 1. [Data Cleaning: Spray](#Spray)
# 1. [Data Cleaning & EDA: Train](#Train)
# 1. [Data Cleaning: Test](#Test)
# 1. [Data Cleaning: Feature Engineering](#Feature-Engineering)

# %% [markdown]
# ## Methodology
#
# 1. Examine data
# 1. Clean data.
# 3. Visualize data using plots and maps.
# 4. Iteratively select features, engineer new features, and model data.
# 5. Finalize model for evaluation.
#
# **Metrics**: We take the AUROC score (also the Kaggle default) as the primary metric, and also examine recall.
#
# - AUROC provides some balance between costs and benefits
# - Precision: Choose to avoid false positives (spray costs priority)
# - Recall: Avoid false negatives (save the people priority)

# %% [markdown]
# #### Data Dictionary
# We have processed this data into the following fields:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |date|<i>datetime</i>|final_train|Date of observation|
# |species|<i>object</i>|final_train|Mosquito species|
# |latitude|<i>float</i>|final_train|Latitude of observation|
# |longitude|<i>float</i>|final_train|Longitude of observation|
# |nummosquitos|<i>int</i>|final_train|Num of mosquitoes observed|
# |wnvpresent|<i>int</i>|final_train|Presence of west nile virus where 1 is present and 0 is not present|
# |longitude|<i>float</i>|final_train|Longitude of observation|
# |year|<i>int</i>|final_train|Year of observation|
# |weekofyear|<i>int</i>|final_train|Week of the year|
# |dum_species|<i>int</i>|final_train|Species where west nile virus might be present|
# |tavg|<i>float</i>|final_train|Average temperature (celsius) of each day of the observation|
# |preciptotal|<i>float</i>|final_train|Total precipitation recorded (inches) on each day of the observation|
# |stnpressure|<i>float</i>|final_train|Average station pressure (inches of HG)|
# |sealevel|<i>float</i>|final_train|Average sea level pressure (inches of HG)|
# |resultspeed|<i>float</i>|final_train|Resultant wind speed (miles per hour)|
# |resultdir|<i>float</i>|final_train|Resultant wind direction (To tens of whole degrees)|
# |resultspeed|<i>float</i>|final_train|Resultant wind speed (miles per hour)|
# |avgspeed|<i>float</i>|final_train|Average speed (miles per hour)|
# |humidity|<i>float</i>|final_train|Relative humidity, calculated using tavg in celsius and dewpoint|
# |daylength|<i>float</i>|final_train|Length of the day, calculated using sunrise and sunset|
# |tavg_lag14|<i>float</i>|final_train|Average temperature (celsius), with 14 lag days|
# |humidity_lag14|<i>float</i>|final_train|Relative humidity, with 14 lag days|
# |preciptotal_lag14|<i>float</i>|final_train|Total precipitation recorded (inches), with 14 lag days|
# |resultspeed_lag14|<i>float</i>|final_train|Resultant wind speed (miles per hour), with 14 lag days|

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Summary of what was cleaned:
# - Null values
# - Lower case column features
# - Change data types
# - Dropped columns (e.g. repeated features)
#
# Details below.

# %% [markdown]
# #### Import

# %%
# import all libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import datetime

# !pip install suntime
from suntime import Sun, SunTimeException
from pytz import timezone
import pytz

# allow pandas to display all columns as dataset has a total of 81 columns
pd.set_option("display.max_columns", 150)
pd.set_option("display.max_rows", 150)

# %%
weather = pd.read_csv("../datasets/weather.csv")
train = pd.read_csv("../datasets/train.csv")
test = pd.read_csv("../datasets/test.csv")
spray = pd.read_csv("../datasets/spray.csv")

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# #### Functions

# %%
def check_missing_data(column):
    return weather[weather[column] == "M"]

# %%
def impute_missing_data(column):
    for k, v in enumerate(weather[column]):
        if v == "M" and weather.iloc[k]["Station"] == 1:
            weather.loc[k, column] = weather[column][k + 1]
        if v == "M" and weather.iloc[k]["Station"] == 2:
            weather.loc[k, column] = weather[column][k - 1]
    weather[column] = weather[column].astype(int)

# %%
def impute_missing_float_data(column):
    for k, v in enumerate(weather[column]):
        if v == "M" and weather.iloc[k]["Station"] == 1:
            weather.loc[k, column] = weather[column][k + 1]
        if v == "M" and weather.iloc[k]["Station"] == 2:
            weather.loc[k, column] = weather[column][k - 1]
    weather[column] = weather[column].astype(float)

# %%
def to_celsius(temp):
    celsius = ((temp - 32.0) * 5.0) / 9.0
    return float(celsius)

# %%
def humidity(row):
    row["Humidity"] = round(
        100
        * (
            np.exp((17.625 * row["DewPoint"]) / (243.04 + row["DewPoint"]))
            / np.exp((17.625 * row["Tavg"]) / (243.04 + row["Tavg"]))
        )
    )
    return row

# %%
def daylength(time):
    min = (time // 100) * 60
    min += time % 100
    return min

# %%
def cleaner(df):
    # change title to lower case
    df.columns = df.columns.str.lower()

    # drop unnecessary columns
    try:
        df.drop(
            columns=[
                "addressaccuracy",
                "addressnumberandstreet",
                "address",
                "block",
                "street",
            ],
            inplace=True,
        )
    except KeyError:
        pass

    # convert date time
    df["date"] = pd.to_datetime(df["date"], format="%Y-%m-%d")

    # create year, month/week in dataset
    df["year"] = (df["date"].dt.strftime("%Y")).astype(int)
    df["weekofyear"] = df.date.dt.isocalendar().week

    # total mozzies as integer
    try:
        df["nummosquitos"] = df["nummosquitos"].astype("int64")
    except KeyError:
        pass

    # display final datatypes
    display(df.dtypes)

# %%
def dum_wkyr(dataset):

    # dummify weekofyear
    dataset = pd.get_dummies(dataset, columns=["weekofyear"], prefix="dumweek")

    # only weeks 28-39 are significant
    # drop all other dummified weeks

    try:
        dataset.drop(
            columns=[
                "dumweek_22",
                "dumweek_23",
                "dumweek_24",
                "dumweek_25",
                "dumweek_26",
                "dumweek_27",
                "dumweek_40",
                "dumweek_41",
            ],
            inplace=True,
        )
    except KeyError:
        dataset.drop(
            columns=[
                "dumweek_22",
                "dumweek_23",
                "dumweek_24",
                "dumweek_25",
                "dumweek_26",
                "dumweek_27",
                "dumweek_40",
            ],
            inplace=True,
        )
    display(dataset.head())
    return dataset

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# ## Weather

# %% [markdown]
# ###  `Weather` dataframe

# %% [markdown]
# Display first five rows of the weather dataframe

# %%
weather.head()
# Out:
#    Station        Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 0        1  2007-05-01    83    50   67     14        51      56    0    2
# 1        2  2007-05-01    84    52   68      M        51      57    0    3
# 2        1  2007-05-02    59    42   51     -3        42      47   14    0
# 3        2  2007-05-02    60    43   52      M        42      47   13    0
# 4        1  2007-05-03    66    46   56      2        40      48    9    0
#
#   Sunrise Sunset CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 0    0448   1849             0      M      0.0        0.00       29.10
# 1       -      -             M      M        M        0.00       29.18
# 2    0447   1850      BR     0      M      0.0        0.00       29.38
# 3       -      -   BR HZ     M      M        M        0.00       29.44
# 4    0446   1851             0      M      0.0        0.00       29.39
#
#   SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 0    29.82          1.7         27      9.2
# 1    29.82          2.7         25      9.6
# 2    30.09         13.0          4     13.4
# 3    30.08         13.3          2     13.4
# 4    30.12         11.7          7     11.9

# %% [markdown]
# Check the number of observations and columns, and the dytpe of the columns

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   object
#  2   Tmax         2944 non-null   int64
#  3   Tmin         2944 non-null   int64
#  4   Tavg         2944 non-null   object
#  5   Depart       2944 non-null   object
#  6   DewPoint     2944 non-null   int64
#  7   WetBulb      2944 non-null   object
#  8   Heat         2944 non-null   object
#  9   Cool         2944 non-null   object
#  10  Sunrise      2944 non-null   object
#  11  Sunset       2944 non-null   object
#  12  CodeSum      2944 non-null   object
#  13  Depth        2944 non-null   object
#  14  Water1       2944 non-null   object
#  15  SnowFall     2944 non-null   object
#  16  PrecipTotal  2944 non-null   object
#  17  StnPressure  2944 non-null   object
#  18  SeaLevel     2944 non-null   object
#  19  ResultSpeed  2944 non-null   float64
#  20  ResultDir    2944 non-null   int64
#  21  AvgSpeed     2944 non-null   object
# dtypes: float64(1), int64(5), object(16)
# memory usage: 506.1+ KB

# %% [markdown]
# Check if there are any null values

# %%
weather.isnull().sum()
# Out:
# Station        0
# Date           0
# Tmax           0
# Tmin           0
# Tavg           0
# Depart         0
# DewPoint       0
# WetBulb        0
# Heat           0
# Cool           0
# Sunrise        0
# Sunset         0
# CodeSum        0
# Depth          0
# Water1         0
# SnowFall       0
# PrecipTotal    0
# StnPressure    0
# SeaLevel       0
# ResultSpeed    0
# ResultDir      0
# AvgSpeed       0
# dtype: int64

# %% [markdown]
# As per weather documentation:<br>
#     M = Missing Data, or data that are not normally reported for the station. <br>
#     - = values not available for sunrise/sunset.<br>
#     T = value is more than 0 but too little to be measured.
#
# Check for 'M', '-', and '  T'

# %%
weather.isin(["  T"]).sum()[weather.isin(["  T"]).sum() > 0]
# Out:
# SnowFall        12
# PrecipTotal    318
# dtype: int64

# %%
weather.isin(["M"]).sum()[weather.isin(["M"]).sum() > 0]
# Out:
# Tavg             11
# Depart         1472
# WetBulb           4
# Heat             11
# Cool             11
# Depth          1472
# Water1         2944
# SnowFall       1472
# PrecipTotal       2
# StnPressure       4
# SeaLevel          9
# AvgSpeed          3
# dtype: int64

# %%
weather.isin(["-"]).sum()
# Out:
# Station           0
# Date              0
# Tmax              0
# Tmin              0
# Tavg              0
# Depart            0
# DewPoint          0
# WetBulb           0
# Heat              0
# Cool              0
# Sunrise        1472
# Sunset         1472
# CodeSum           0
# Depth             0
# Water1            0
# SnowFall          0
# PrecipTotal       0
# StnPressure       0
# SeaLevel          0
# ResultSpeed       0
# ResultDir         0
# AvgSpeed          0
# dtype: int64

# %% [markdown]
# ### Cleaning for Weather

# %% [markdown]
# Convert date to datetime

# %%
weather["Date"] = pd.to_datetime(weather["Date"], format="%Y-%m-%d")

# %% [markdown]
# #### Tavg
# Tavg is the average of Tmin and Tmax, hence we will impute Tavg using the avaerage of Tmin and Tmax.

# %% [markdown]
# Check for missing date represented by 'M' using function that was created.

# %%
check_missing_data("Tavg")
# Out:
#       Station       Date  Tmax  Tmin Tavg Depart  DewPoint WetBulb Heat Cool  \
# 7           2 2007-05-04    78    51    M      M        42      50    M    M
# 505         2 2008-07-08    86    46    M      M        68      71    M    M
# 675         2 2008-10-01    62    46    M      M        41      47    M    M
# 1637        2 2011-07-22   100    71    M      M        70      74    M    M
# 2067        2 2012-08-22    84    72    M      M        51      61    M    M
# 2211        2 2013-05-02    71    42    M      M        39      45    M    M
# 2501        2 2013-09-24    91    52    M      M        48      54    M    M
# 2511        2 2013-09-29    84    53    M      M        48      54    M    M
# 2525        2 2013-10-06    76    48    M      M        44      50    M    M
# 2579        2 2014-05-02    80    47    M      M        43      47    M    M
# 2811        2 2014-08-26    86    49    M      M        68      71    M    M
#
#      Sunrise Sunset     CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 7          -      -                 M      M        M        0.00       29.36
# 505        -      -       TS RA     M      M        M        0.28       29.16
# 675        -      -                 M      M        M        0.00       29.30
# 1637       -      -  TS TSRA BR     M      M        M        0.14       29.23
# 2067       -      -                 M      M        M        0.00       29.39
# 2211       -      -                 M      M        M        0.00       29.51
# 2501       -      -                 M      M        M        0.00       29.33
# 2511       -      -       RA BR     M      M        M        0.22       29.36
# 2525       -      -    RA DZ BR     M      M        M        0.06       29.10
# 2579       -      -          RA     M      M        M        0.04       29.10
# 2811       -      -                 M      M        M           T       29.41
#
#      SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 7       30.04         10.1          7     10.4
# 505     29.80          7.4         24      8.3
# 675     29.96         10.9         33     11.0
# 1637    29.86          3.8         10      8.2
# 2067        M          4.7         19        M
# 2211    30.17         15.8          2     16.1
# 2501    30.00          5.8          9      7.7
# 2511    30.01          6.3         36      7.8
# 2525    29.76         10.1         25     10.6
# 2579    29.79         10.7         23     11.9
# 2811    30.04          1.3         15      5.8

# %%
weather["Tavg"] = weather.apply(
    lambda x: (x.Tmax + x.Tmin) / 2 if x.Tavg == "M" else x.Tavg, axis=1
)

# %% [markdown]
# Convert dtype from object to float

# %%
weather["Tavg"] = weather["Tavg"].astype(float)

# %%
weather["Tavg"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Tmin

# %%
weather['Tmin'].value_counts()
# Out:
# 63    121
# 65    111
# 60    109
# 61    106
# 62    105
# 57    103
# 68    103
# 66    103
# 64    101
# 59    100
# 56     98
# 71     95
# 69     95
# 58     94
# 70     90
# 67     89
# 54     81
# 49     78
# 52     74
# 50     72
# 53     71
# 55     71
# 47     69
# 44     59
# 46     58
# 43     58
# 51     57
# 45     55
# 48     55
# 72     50
# 42     46
# 73     46
# 41     38
# 40     33
# 74     29
# 39     29
# 75     28
# 38     22
# 37     21
# 77     20
# 36     20
# 34     12
# 35     11
# 33     10
# 79      9
# 32      7
# 31      7
# 29      6
# 76      6
# 78      4
# 80      3
# 81      3
# 82      2
# 83      1
# Name: Tmin, dtype: int64

# %% [markdown]
# Convert dtype to float

# %%
weather["Tmin"] = weather["Tmin"].astype(float)

# %% [markdown]
# #### Tmax

# %%
weather["Tmax"].value_counts()
# Out:
# 84     128
# 79     121
# 82     118
# 81     117
# 83     109
# 85     107
# 80     107
# 86     101
# 77     100
# 87      97
# 88      91
# 74      85
# 78      84
# 89      83
# 76      79
# 75      79
# 72      72
# 70      71
# 73      65
# 71      64
# 90      62
# 67      62
# 91      61
# 68      60
# 69      60
# 60      50
# 66      50
# 65      46
# 63      43
# 62      43
# 61      41
# 92      40
# 64      39
# 93      34
# 59      31
# 55      29
# 56      28
# 94      28
# 57      27
# 58      26
# 53      25
# 54      23
# 50      19
# 51      18
# 95      16
# 52      13
# 49      12
# 96      11
# 48      11
# 47       9
# 46       9
# 97       6
# 45       5
# 44       5
# 99       5
# 98       5
# 101      4
# 100      3
# 103      2
# 102      2
# 42       1
# 41       1
# 104      1
# Name: Tmax, dtype: int64

# %% [markdown]
# Covert dtype to float.

# %%
weather["Tmax"] = weather["Tmax"].astype(float)

# %% [markdown]
# #### Depart

# %% [markdown]
# Check for missing date represented by 'M' using function that was created.

# %%
check_missing_data("Depart")
# Out:
#       Station       Date  Tmax  Tmin  Tavg Depart  DewPoint WetBulb Heat Cool  \
# 1           2 2007-05-01  84.0  52.0  68.0      M        51      57    0    3
# 3           2 2007-05-02  60.0  43.0  52.0      M        42      47   13    0
# 5           2 2007-05-03  67.0  48.0  58.0      M        40      50    7    0
# 7           2 2007-05-04  78.0  51.0  64.5      M        42      50    M    M
# 9           2 2007-05-05  66.0  54.0  60.0      M        39      50    5    0
# ...       ...        ...   ...   ...   ...    ...       ...     ...  ...  ...
# 2935        2 2014-10-27  79.0  54.0  67.0      M        52      59    0    2
# 2937        2 2014-10-28  66.0  48.0  57.0      M        40      48    8    0
# 2939        2 2014-10-29  49.0  40.0  45.0      M        34      42   20    0
# 2941        2 2014-10-30  53.0  37.0  45.0      M        35      42   20    0
# 2943        2 2014-10-31  49.0  34.0  42.0      M        29      36   23    0
#
#      Sunrise Sunset   CodeSum Depth Water1 SnowFall PrecipTotal StnPressure  \
# 1          -      -               M      M        M        0.00       29.18
# 3          -      -     BR HZ     M      M        M        0.00       29.44
# 5          -      -        HZ     M      M        M        0.00       29.46
# 7          -      -               M      M        M        0.00       29.36
# 9          -      -               M      M        M           T       29.46
# ...      ...    ...       ...   ...    ...      ...         ...         ...
# 2935       -      -        RA     M      M        M        0.02       29.00
# 2937       -      -        RA     M      M        M        0.03       29.23
# 2939       -      -               M      M        M        0.00       29.42
# 2941       -      -        RA     M      M        M           T       29.41
# 2943       -      -  RA SN BR     M      M        M        0.04       29.54
#
#      SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 1       29.82          2.7         25      9.6
# 3       30.08         13.3          2     13.4
# 5       30.12         12.9          6     13.2
# 7       30.04         10.1          7     10.4
# 9       30.09         11.2          7     11.5
# ...       ...          ...        ...      ...
# 2935    29.67         12.7         19     13.6
# 2937    29.85         14.0         26     14.6
# 2939    30.07          8.5         29      9.0
# 2941    30.10          5.9         23      6.5
# 2943    30.20         21.7         34     22.6
#
# [1472 rows x 22 columns]

# %% [markdown]
# Impute missing data using function created. Function uses Depart values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to int.

# %%
impute_missing_data("Depart")

# %%
weather["Depart"].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### WetBulb

# %% [markdown]
# Check for missing date represented by 'M' using function that was created.

# %%
check_missing_data("WetBulb")
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint WetBulb Heat  \
# 848         1 2009-06-26  86.0  69.0  78.0       7        60       M    0
# 2410        1 2013-08-10  81.0  64.0  73.0       0        57       M    0
# 2412        1 2013-08-11  81.0  60.0  71.0      -2        61       M    0
# 2415        2 2013-08-12  85.0  69.0  77.0       2        63       M    0
#
#      Cool Sunrise Sunset CodeSum Depth Water1 SnowFall PrecipTotal  \
# 848    13    0418   1931             0      M      0.0        0.00
# 2410    8    0454   1900             0      M      0.0        0.00
# 2412    6    0455   1859      RA     0      M      0.0        0.01
# 2415   12       -      -      RA     M      M        M        0.66
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 848            M    29.85          6.4          4      8.2
# 2410           M    30.08          5.3          5      6.5
# 2412       29.35    30.07          2.0         27      3.0
# 2415       29.27    29.92          4.5         26      7.7

# %% [markdown]
# Impute missing data using function created. Function uses Wetbulb values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to int.

# %%
impute_missing_data("WetBulb")

# %%
weather["WetBulb"].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### Heat

# %% [markdown]
# Check for missing date represented by 'M' using function that was created.

# %%
check_missing_data("Heat")
# Out:
#       Station       Date   Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb Heat  \
# 7           2 2007-05-04   78.0  51.0  64.5       4        42       50    M
# 505         2 2008-07-08   86.0  46.0  66.0       5        68       71    M
# 675         2 2008-10-01   62.0  46.0  54.0      -4        41       47    M
# 1637        2 2011-07-22  100.0  71.0  85.5       5        70       74    M
# 2067        2 2012-08-22   84.0  72.0  78.0      -1        51       61    M
# 2211        2 2013-05-02   71.0  42.0  56.5      -5        39       45    M
# 2501        2 2013-09-24   91.0  52.0  71.5      -1        48       54    M
# 2511        2 2013-09-29   84.0  53.0  68.5       1        48       54    M
# 2525        2 2013-10-06   76.0  48.0  62.0      -1        44       50    M
# 2579        2 2014-05-02   80.0  47.0  63.5      -4        43       47    M
# 2811        2 2014-08-26   86.0  49.0  67.5       8        68       71    M
#
#      Cool Sunrise Sunset     CodeSum Depth Water1 SnowFall PrecipTotal  \
# 7       M       -      -                 M      M        M        0.00
# 505     M       -      -       TS RA     M      M        M        0.28
# 675     M       -      -                 M      M        M        0.00
# 1637    M       -      -  TS TSRA BR     M      M        M        0.14
# 2067    M       -      -                 M      M        M        0.00
# 2211    M       -      -                 M      M        M        0.00
# 2501    M       -      -                 M      M        M        0.00
# 2511    M       -      -       RA BR     M      M        M        0.22
# 2525    M       -      -    RA DZ BR     M      M        M        0.06
# 2579    M       -      -          RA     M      M        M        0.04
# 2811    M       -      -                 M      M        M           T
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 7          29.36    30.04         10.1          7     10.4
# 505        29.16    29.80          7.4         24      8.3
# 675        29.30    29.96         10.9         33     11.0
# 1637       29.23    29.86          3.8         10      8.2
# 2067       29.39        M          4.7         19        M
# 2211       29.51    30.17         15.8          2     16.1
# 2501       29.33    30.00          5.8          9      7.7
# 2511       29.36    30.01          6.3         36      7.8
# 2525       29.10    29.76         10.1         25     10.6
# 2579       29.10    29.79         10.7         23     11.9
# 2811       29.41    30.04          1.3         15      5.8

# %% [markdown]
# Impute missing data using function created. Function uses Heat values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to int.

# %%
impute_missing_data("Heat")

# %%
weather["Heat"].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### Cool

# %% [markdown]
# Check for missing date represented by 'M' using function that was created.

# %%
check_missing_data("Cool")
# Out:
#       Station       Date   Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 7           2 2007-05-04   78.0  51.0  64.5       4        42       50     7
# 505         2 2008-07-08   86.0  46.0  66.0       5        68       71     0
# 675         2 2008-10-01   62.0  46.0  54.0      -4        41       47    11
# 1637        2 2011-07-22  100.0  71.0  85.5       5        70       74     0
# 2067        2 2012-08-22   84.0  72.0  78.0      -1        51       61     0
# 2211        2 2013-05-02   71.0  42.0  56.5      -5        39       45    16
# 2501        2 2013-09-24   91.0  52.0  71.5      -1        48       54     5
# 2511        2 2013-09-29   84.0  53.0  68.5       1        48       54     5
# 2525        2 2013-10-06   76.0  48.0  62.0      -1        44       50    10
# 2579        2 2014-05-02   80.0  47.0  63.5      -4        43       47    15
# 2811        2 2014-08-26   86.0  49.0  67.5       8        68       71     0
#
#      Cool Sunrise Sunset     CodeSum Depth Water1 SnowFall PrecipTotal  \
# 7       M       -      -                 M      M        M        0.00
# 505     M       -      -       TS RA     M      M        M        0.28
# 675     M       -      -                 M      M        M        0.00
# 1637    M       -      -  TS TSRA BR     M      M        M        0.14
# 2067    M       -      -                 M      M        M        0.00
# 2211    M       -      -                 M      M        M        0.00
# 2501    M       -      -                 M      M        M        0.00
# 2511    M       -      -       RA BR     M      M        M        0.22
# 2525    M       -      -    RA DZ BR     M      M        M        0.06
# 2579    M       -      -          RA     M      M        M        0.04
# 2811    M       -      -                 M      M        M           T
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 7          29.36    30.04         10.1          7     10.4
# 505        29.16    29.80          7.4         24      8.3
# 675        29.30    29.96         10.9         33     11.0
# 1637       29.23    29.86          3.8         10      8.2
# 2067       29.39        M          4.7         19        M
# 2211       29.51    30.17         15.8          2     16.1
# 2501       29.33    30.00          5.8          9      7.7
# 2511       29.36    30.01          6.3         36      7.8
# 2525       29.10    29.76         10.1         25     10.6
# 2579       29.10    29.79         10.7         23     11.9
# 2811       29.41    30.04          1.3         15      5.8

# %% [markdown]
# Impute missing data using function created. Function uses Cool values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to int.

# %%
impute_missing_data("Cool")

# %%
weather["Cool"].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### Sunrise and Sunset

# %% [markdown]
# Check for missing sunrise values.

# %%
weather[weather["Sunrise"] == "-"]
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 1           2 2007-05-01  84.0  52.0  68.0      14        51       57     0
# 3           2 2007-05-02  60.0  43.0  52.0      -3        42       47    13
# 5           2 2007-05-03  67.0  48.0  58.0       2        40       50     7
# 7           2 2007-05-04  78.0  51.0  64.5       4        42       50     7
# 9           2 2007-05-05  66.0  54.0  60.0       5        39       50     5
# ...       ...        ...   ...   ...   ...     ...       ...      ...   ...
# 2935        2 2014-10-27  79.0  54.0  67.0      16        52       59     0
# 2937        2 2014-10-28  66.0  48.0  57.0      10        40       48     8
# 2939        2 2014-10-29  49.0  40.0  45.0      -4        34       42    20
# 2941        2 2014-10-30  53.0  37.0  45.0      -4        35       42    20
# 2943        2 2014-10-31  49.0  34.0  42.0      -6        29       36    23
#
#       Cool Sunrise Sunset   CodeSum Depth Water1 SnowFall PrecipTotal  \
# 1        3       -      -               M      M        M        0.00
# 3        0       -      -     BR HZ     M      M        M        0.00
# 5        0       -      -        HZ     M      M        M        0.00
# 7        0       -      -               M      M        M        0.00
# 9        0       -      -               M      M        M           T
# ...    ...     ...    ...       ...   ...    ...      ...         ...
# 2935     2       -      -        RA     M      M        M        0.02
# 2937     0       -      -        RA     M      M        M        0.03
# 2939     0       -      -               M      M        M        0.00
# 2941     0       -      -        RA     M      M        M           T
# 2943     0       -      -  RA SN BR     M      M        M        0.04
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 1          29.18    29.82          2.7         25      9.6
# 3          29.44    30.08         13.3          2     13.4
# 5          29.46    30.12         12.9          6     13.2
# 7          29.36    30.04         10.1          7     10.4
# 9          29.46    30.09         11.2          7     11.5
# ...          ...      ...          ...        ...      ...
# 2935       29.00    29.67         12.7         19     13.6
# 2937       29.23    29.85         14.0         26     14.6
# 2939       29.42    30.07          8.5         29      9.0
# 2941       29.41    30.10          5.9         23      6.5
# 2943       29.54    30.20         21.7         34     22.6
#
# [1472 rows x 22 columns]

# %% [markdown]
# Check for sunset missing values

# %%
weather[weather["Sunset"] == "-"]
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 1           2 2007-05-01  84.0  52.0  68.0      14        51       57     0
# 3           2 2007-05-02  60.0  43.0  52.0      -3        42       47    13
# 5           2 2007-05-03  67.0  48.0  58.0       2        40       50     7
# 7           2 2007-05-04  78.0  51.0  64.5       4        42       50     7
# 9           2 2007-05-05  66.0  54.0  60.0       5        39       50     5
# ...       ...        ...   ...   ...   ...     ...       ...      ...   ...
# 2935        2 2014-10-27  79.0  54.0  67.0      16        52       59     0
# 2937        2 2014-10-28  66.0  48.0  57.0      10        40       48     8
# 2939        2 2014-10-29  49.0  40.0  45.0      -4        34       42    20
# 2941        2 2014-10-30  53.0  37.0  45.0      -4        35       42    20
# 2943        2 2014-10-31  49.0  34.0  42.0      -6        29       36    23
#
#       Cool Sunrise Sunset   CodeSum Depth Water1 SnowFall PrecipTotal  \
# 1        3       -      -               M      M        M        0.00
# 3        0       -      -     BR HZ     M      M        M        0.00
# 5        0       -      -        HZ     M      M        M        0.00
# 7        0       -      -               M      M        M        0.00
# 9        0       -      -               M      M        M           T
# ...    ...     ...    ...       ...   ...    ...      ...         ...
# 2935     2       -      -        RA     M      M        M        0.02
# 2937     0       -      -        RA     M      M        M        0.03
# 2939     0       -      -               M      M        M        0.00
# 2941     0       -      -        RA     M      M        M           T
# 2943     0       -      -  RA SN BR     M      M        M        0.04
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 1          29.18    29.82          2.7         25      9.6
# 3          29.44    30.08         13.3          2     13.4
# 5          29.46    30.12         12.9          6     13.2
# 7          29.36    30.04         10.1          7     10.4
# 9          29.46    30.09         11.2          7     11.5
# ...          ...      ...          ...        ...      ...
# 2935       29.00    29.67         12.7         19     13.6
# 2937       29.23    29.85         14.0         26     14.6
# 2939       29.42    30.07          8.5         29      9.0
# 2941       29.41    30.10          5.9         23      6.5
# 2943       29.54    30.20         21.7         34     22.6
#
# [1472 rows x 22 columns]

# %% [markdown]
# Impute missing data using suntime for sunrise and sunset timing based on latitude and longitude of the weather station 2, since only weather station 2 has missing values.

# %%
latitude = 41.786
longitude = -87.752

sun = Sun(latitude, longitude)

central = timezone("US/Central")

sunrise_list = []
sunset_list = []
for value in weather["Date"]:
    abd = value
    abd_sr = sun.get_local_sunrise_time(value, local_time_zone=central)
    abd_sr = abd_sr - abd_sr.dst()
    abd_ss = sun.get_local_sunset_time(value, local_time_zone=central)
    abd_ss = abd_ss - abd_ss.dst()
    sunrise_list.append(abd_sr.strftime("%H%M"))
    sunset_list.append(abd_ss.strftime("%H%M"))

# %%
index = weather.loc[weather["Station"] == 2].index

for i in index:
    weather.loc[i, "Sunrise"] = sunrise_list[i]
    weather.loc[i, "Sunset"] = sunset_list[i]

# %%
# Check updated values
weather[["Sunrise", "Sunset"]][weather["Station"] == 2]
# Out:
#      Sunrise Sunset
# 1       0448   1849
# 3       0447   1850
# 5       0445   1851
# 7       0444   1852
# 9       0443   1853
# ...      ...    ...
# 2935    0617   1652
# 2937    0618   1651
# 2939    0620   1649
# 2941    0621   1648
# 2943    0622   1647
#
# [1472 rows x 2 columns]

# %% [markdown]
# #### SnowFall
# 'T' which represents 'Trace', denotes that there is an amount of precipitation, which is greater than zero but is too small to be measured. The lowest value in SnowFall is 0 and the second lowest is 0.1, hence we will impute 'T' with the mean of these 2 numbers, which is 0.05.

# %%
weather.loc[weather["SnowFall"] == "  T", "SnowFall"] = 0.05

# %%
check_missing_data("SnowFall")
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 1           2 2007-05-01  84.0  52.0  68.0      14        51       57     0
# 3           2 2007-05-02  60.0  43.0  52.0      -3        42       47    13
# 5           2 2007-05-03  67.0  48.0  58.0       2        40       50     7
# 7           2 2007-05-04  78.0  51.0  64.5       4        42       50     7
# 9           2 2007-05-05  66.0  54.0  60.0       5        39       50     5
# ...       ...        ...   ...   ...   ...     ...       ...      ...   ...
# 2935        2 2014-10-27  79.0  54.0  67.0      16        52       59     0
# 2937        2 2014-10-28  66.0  48.0  57.0      10        40       48     8
# 2939        2 2014-10-29  49.0  40.0  45.0      -4        34       42    20
# 2941        2 2014-10-30  53.0  37.0  45.0      -4        35       42    20
# 2943        2 2014-10-31  49.0  34.0  42.0      -6        29       36    23
#
#       Cool Sunrise Sunset   CodeSum Depth Water1 SnowFall PrecipTotal  \
# 1        3    0448   1849               M      M        M        0.00
# 3        0    0447   1850     BR HZ     M      M        M        0.00
# 5        0    0445   1851        HZ     M      M        M        0.00
# 7        0    0444   1852               M      M        M        0.00
# 9        0    0443   1853               M      M        M           T
# ...    ...     ...    ...       ...   ...    ...      ...         ...
# 2935     2    0617   1652        RA     M      M        M        0.02
# 2937     0    0618   1651        RA     M      M        M        0.03
# 2939     0    0620   1649               M      M        M        0.00
# 2941     0    0621   1648        RA     M      M        M           T
# 2943     0    0622   1647  RA SN BR     M      M        M        0.04
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 1          29.18    29.82          2.7         25      9.6
# 3          29.44    30.08         13.3          2     13.4
# 5          29.46    30.12         12.9          6     13.2
# 7          29.36    30.04         10.1          7     10.4
# 9          29.46    30.09         11.2          7     11.5
# ...          ...      ...          ...        ...      ...
# 2935       29.00    29.67         12.7         19     13.6
# 2937       29.23    29.85         14.0         26     14.6
# 2939       29.42    30.07          8.5         29      9.0
# 2941       29.41    30.10          5.9         23      6.5
# 2943       29.54    30.20         21.7         34     22.6
#
# [1472 rows x 22 columns]

# %% [markdown]
# Impute missing data using function created. Function uses Snowfall values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to float.

# %%
impute_missing_float_data("SnowFall")

# %%
weather["SnowFall"].value_counts()
# Out:
# 0.00    2918
# 0.05      24
# 0.10       2
# Name: SnowFall, dtype: int64

# %%
weather["SnowFall"].dtype
# Out:
# dtype('float64')

# %%
# Minimal snow, can drop column

weather["SnowFall"].sum()
# Out:
# 1.4

# %% [markdown]
# #### PrecipTotal
# 'T' which represents 'Trace', denotes that there is an amount of precipitation, which is greater than zero but is too small to be measured.
#
# The lowest value in PrecipTotal is 0 and the second lowest is 0.01, hence we will impute 'T' with the mean of these 2 numbers, which is 0.005.

# %%
weather["PrecipTotal"].value_counts(ascending=False)
# Out:
# 0.00    1577
#   T      318
# 0.01     127
# 0.02      63
# 0.03      46
#         ...
# 2.90       1
# 1.96       1
# 1.07       1
# 1.14       1
# 1.44       1
# Name: PrecipTotal, Length: 168, dtype: int64

# %%
weather.loc[weather["PrecipTotal"] == "  T", "PrecipTotal"] = 0.005

# %% [markdown]
# Check for missing values using Function that was created

# %%
check_missing_data("PrecipTotal")
# Out:
#      Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 117        2 2007-06-28  73.0  61.0  67.0      -5        56       61     0
# 119        2 2007-06-29  71.0  56.0  64.0      -8        56       60     1
#
#      Cool Sunrise Sunset CodeSum Depth Water1  SnowFall PrecipTotal  \
# 117     2    0419   1930             M      M       0.0           M
# 119     0    0419   1930             M      M       0.0           M
#
#     StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 117       29.43    30.07         12.2          2     13.3
# 119       29.47    30.11          7.4          2      8.2

# %% [markdown]
# Impute missing data using function created. Function uses PrecipTotal values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to float.

# %%
impute_missing_float_data("PrecipTotal")

# %%
weather["PrecipTotal"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Depth
# Depth has only 2 values. 'M' which denotes missing data or 0. We will look into dropping this column since it does not hold any meaningful data. Meanwhile, we will impute the values with 0 from the other Station. We are likely to drop this column as it only has 1 value once imputation is done.

# %%
weather["Depth"].value_counts()
# Out:
# M    1472
# 0    1472
# Name: Depth, dtype: int64

# %% [markdown]
# Impute missing data using function created. Function uses Depth values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to int.

# %%
impute_missing_data("Depth")

# %%
weather["Depth"].dtype
# Out:
# dtype('int32')

# %% [markdown]
# #### StnPressure

# %% [markdown]
# Check for missing values in 'StnPressure'

# %%
check_missing_data("StnPressure")
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 87          2 2007-06-13  86.0  68.0  77.0       6        53       62     0
# 848         1 2009-06-26  86.0  69.0  78.0       7        60       67     0
# 2410        1 2013-08-10  81.0  64.0  73.0       0        57       63     0
# 2411        2 2013-08-10  81.0  68.0  75.0       0        55       63     0
#
#       Cool Sunrise Sunset CodeSum  Depth Water1  SnowFall  PrecipTotal  \
# 87      12    0416   1926              0      M       0.0          0.0
# 848     13    0418   1931              0      M       0.0          0.0
# 2410     8    0454   1900              0      M       0.0          0.0
# 2411    10    0454   1858              0      M       0.0          0.0
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 87             M        M          7.0          5        M
# 848            M    29.85          6.4          4      8.2
# 2410           M    30.08          5.3          5      6.5
# 2411           M    30.07          6.0          6      7.4

# %% [markdown]
# Data could not be imputed using data from the other Station as both rows do not have any values in 'StnPressure'. Hence, we will check for the 'StnPressure' for the day before and the day after, and impute the missing data with the mean of 'StnPressure' of these two days.

# %%
weather[weather["Date"] == "2013-08-10"]
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 2410        1 2013-08-10  81.0  64.0  73.0       0        57       63     0
# 2411        2 2013-08-10  81.0  68.0  75.0       0        55       63     0
#
#       Cool Sunrise Sunset CodeSum  Depth Water1  SnowFall  PrecipTotal  \
# 2410     8    0454   1900              0      M       0.0          0.0
# 2411    10    0454   1858              0      M       0.0          0.0
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 2410           M    30.08          5.3          5      6.5
# 2411           M    30.07          6.0          6      7.4

# %%
weather[weather["Date"] == "2013-08-09"]
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 2408        1 2013-08-09  82.0  59.0  71.0      -2        60       65     0
# 2409        2 2013-08-09  84.0  62.0  73.0      -2        58       65     0
#
#       Cool Sunrise Sunset CodeSum  Depth Water1  SnowFall  PrecipTotal  \
# 2408     6    0453   1902              0      M       0.0        0.005
# 2409     8    0453   1859              0      M       0.0        0.000
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 2408       29.28    29.98          4.7         27      5.3
# 2409       29.34    29.97          4.9         27      5.6

# %%
weather[weather["Date"] == "2013-08-11"]
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 2412        1 2013-08-11  81.0  60.0  71.0      -2        61       64     0
# 2413        2 2013-08-11  84.0  63.0  74.0      -2        57       64     0
#
#       Cool Sunrise Sunset CodeSum  Depth Water1  SnowFall  PrecipTotal  \
# 2412     6    0455   1859      RA      0      M       0.0        0.010
# 2413     9    0455   1857              0      M       0.0        0.005
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 2412       29.35    30.07          2.0         27      3.0
# 2413       29.42    30.06          4.0         24      5.4

# %%
# Impute according to the average StnPressure of 2013-08-09 and 2013-08-11
weather.at[2410, "StnPressure"] = round((29.28 + 29.34) / 2, 2)
weather.at[2411, "StnPressure"] = round((29.35 + 29.42) / 2, 2)

# %%
weather[weather["Date"] == "2013-08-10"]
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 2410        1 2013-08-10  81.0  64.0  73.0       0        57       63     0
# 2411        2 2013-08-10  81.0  68.0  75.0       0        55       63     0
#
#       Cool Sunrise Sunset CodeSum  Depth Water1  SnowFall  PrecipTotal  \
# 2410     8    0454   1900              0      M       0.0          0.0
# 2411    10    0454   1858              0      M       0.0          0.0
#
#      StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 2410       29.31    30.08          5.3          5      6.5
# 2411       29.39    30.07          6.0          6      7.4

# %% [markdown]
# Impute remaining missing data using function created. Function uses StnPressure values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to float.

# %%
impute_missing_float_data("StnPressure")

# %%
weather["StnPressure"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### SeaLevel

# %% [markdown]
# Check for missing values in 'SeaLevel'

# %%
check_missing_data("SeaLevel")
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 87          2 2007-06-13  86.0  68.0  77.0       6        53       62     0
# 832         1 2009-06-18  80.0  61.0  71.0       1        63       67     0
# 994         1 2009-09-07  77.0  59.0  68.0       1        59       62     0
# 1732        1 2011-09-08  75.0  57.0  66.0       0        53       59     0
# 1745        2 2011-09-14  60.0  48.0  54.0     -11        45       51    11
# 1756        1 2011-09-20  74.0  49.0  62.0       0        54       58     3
# 2067        2 2012-08-22  84.0  72.0  78.0      -1        51       61     0
# 2090        1 2012-09-03  88.0  71.0  80.0      12        70       73     0
# 2743        2 2014-07-23  76.0  64.0  70.0      -7        56       61     0
#
#       Cool Sunrise Sunset       CodeSum  Depth Water1  SnowFall  PrecipTotal  \
# 87      12    0416   1926                    0      M       0.0        0.000
# 832      6    0416   1929         RA BR      0      M       0.0        0.120
# 994      3    0523   1817            BR      0      M       0.0        0.000
# 1732     1    0524   1815            RA      0      M       0.0        0.005
# 1745     0    0530   1802   RA BR HZ FU      0      M       0.0        0.005
# 1756     0    0537   1753  MIFG BCFG BR      0      M       0.0        0.000
# 2067     5    0507   1839                    0      M       0.0        0.000
# 2090    15    0519   1824            BR      0      M       0.0        0.000
# 2743     5    0436   1918                    0      M       0.0        0.000
#
#       StnPressure SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 87          29.36        M          7.0          5        M
# 832         29.08        M          6.7         16      7.9
# 994         29.39        M          5.8          3      4.0
# 1732        29.34        M         13.0          2     13.4
# 1745        29.47        M          6.0         32        M
# 1756        29.26        M          7.3         18      7.3
# 2067        29.39        M          4.7         19        M
# 2090        29.17        M          4.6          6      4.4
# 2743        29.47        M         16.4          2     16.7

# %% [markdown]
# Impute missing data using function created. Function uses SeaLevel values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to float.

# %%
impute_missing_float_data("SeaLevel")

# %%
weather["SeaLevel"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### AvgSpeed

# %% [markdown]
# Check for missing values in 'AvgSpeed'

# %%
check_missing_data("AvgSpeed")
# Out:
#       Station       Date  Tmax  Tmin  Tavg  Depart  DewPoint  WetBulb  Heat  \
# 87          2 2007-06-13  86.0  68.0  77.0       6        53       62     0
# 1745        2 2011-09-14  60.0  48.0  54.0     -11        45       51    11
# 2067        2 2012-08-22  84.0  72.0  78.0      -1        51       61     0
#
#       Cool Sunrise Sunset      CodeSum  Depth Water1  SnowFall  PrecipTotal  \
# 87      12    0416   1926                   0      M       0.0        0.000
# 1745     0    0530   1802  RA BR HZ FU      0      M       0.0        0.005
# 2067     5    0507   1839                   0      M       0.0        0.000
#
#       StnPressure  SeaLevel  ResultSpeed  ResultDir AvgSpeed
# 87          29.36     30.09          7.0          5        M
# 1745        29.47     30.09          6.0         32        M
# 2067        29.39     30.07          4.7         19        M

# %% [markdown]
# Impute missing data using function created. Function uses AvgSpeed values from the other Station as the distance between Station 1 and 2 is not big. The function also converts the dtype to float.

# %%
impute_missing_float_data("AvgSpeed")

# %%
weather["AvgSpeed"].dtype
# Out:
# dtype('float64')

# %%
weather.isin(["  T"]).sum()[weather.isin(["  T"]).sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
weather.isin(["M"]).sum()[weather.isin(["M"]).sum() > 0]
# Out:
# Water1    2944
# dtype: int64

# %% [markdown]
# #### Relative Humidity
# Climate can affect the geographic and seasonal patterns of vector-borne disease incidence such as West Nile Virus (WNV) infections. High relative humidity is believed to be a strong factor in the breeding of mosquitos, which may increase the spread of WNV.
#
# Formula to calculate relative humidity: [source](https://bmcnoldy.rsmas.miami.edu/Humidity.html).
# Formula uses celsius as inputs and outputs, hence we will convert all temperature to celsius using the function we created, and use 'DewPoint' and 'Tavg' in our 'Humidity' function to get the relative humidity of each observation.

# %%
weather["Tavg"] = weather["Tavg"].apply(to_celsius)
weather["Tmin"] = weather["Tmin"].apply(to_celsius)
weather["Tmax"] = weather["Tmax"].apply(to_celsius)

# %%
weather["DewPoint"] = weather["DewPoint"].apply(to_celsius)

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   datetime64[ns]
#  2   Tmax         2944 non-null   float64
#  3   Tmin         2944 non-null   float64
#  4   Tavg         2944 non-null   float64
#  5   Depart       2944 non-null   int32
#  6   DewPoint     2944 non-null   float64
#  7   WetBulb      2944 non-null   int32
#  8   Heat         2944 non-null   int32
#  9   Cool         2944 non-null   int32
#  10  Sunrise      2944 non-null   object
#  11  Sunset       2944 non-null   object
#  12  CodeSum      2944 non-null   object
#  13  Depth        2944 non-null   int32
#  14  Water1       2944 non-null   object
#  15  SnowFall     2944 non-null   float64
#  16  PrecipTotal  2944 non-null   float64
#  17  StnPressure  2944 non-null   float64
#  18  SeaLevel     2944 non-null   float64
#  19  ResultSpeed  2944 non-null   float64
#  20  ResultDir    2944 non-null   int64
#  21  AvgSpeed     2944 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int32(5), int64(2), object(4)
# memory usage: 448.6+ KB

# %% [markdown]
# Use 'Humidity' function that was created and add humidity values to a new column "Humidity'

# %%
weather = weather.apply(humidity, axis=1)

# %%
weather
# Out:
#       Station       Date       Tmax       Tmin       Tavg  Depart   DewPoint  \
# 0           1 2007-05-01  28.333333  10.000000  19.444444      14  10.555556
# 1           2 2007-05-01  28.888889  11.111111  20.000000      14  10.555556
# 2           1 2007-05-02  15.000000   5.555556  10.555556      -3   5.555556
# 3           2 2007-05-02  15.555556   6.111111  11.111111      -3   5.555556
# 4           1 2007-05-03  18.888889   7.777778  13.333333       2   4.444444
# ...       ...        ...        ...        ...        ...     ...        ...
# 2939        2 2014-10-29   9.444444   4.444444   7.222222      -4   1.111111
# 2940        1 2014-10-30  10.555556   0.000000   5.555556      -4   1.111111
# 2941        2 2014-10-30  11.666667   2.777778   7.222222      -4   1.666667
# 2942        1 2014-10-31   8.333333   0.555556   4.444444      -6  -3.888889
# 2943        2 2014-10-31   9.444444   1.111111   5.555556      -6  -1.666667
#
#       WetBulb  Heat  Cool Sunrise Sunset   CodeSum  Depth Water1  SnowFall  \
# 0          56     0     2    0448   1849                0      M       0.0
# 1          57     0     3    0448   1849                0      M       0.0
# 2          47    14     0    0447   1850        BR      0      M       0.0
# 3          47    13     0    0447   1850     BR HZ      0      M       0.0
# 4          48     9     0    0446   1851                0      M       0.0
# ...       ...   ...   ...     ...    ...       ...    ...    ...       ...
# 2939       42    20     0    0620   1649                0      M       0.0
# 2940       40    23     0    0622   1649                0      M       0.0
# 2941       42    20     0    0621   1648        RA      0      M       0.0
# 2942       33    25     0    0623   1647     RA SN      0      M       0.1
# 2943       36    23     0    0622   1647  RA SN BR      0      M       0.1
#
#       PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  AvgSpeed  \
# 0           0.000        29.10     29.82          1.7         27       9.2
# 1           0.000        29.18     29.82          2.7         25       9.6
# 2           0.000        29.38     30.09         13.0          4      13.4
# 3           0.000        29.44     30.08         13.3          2      13.4
# 4           0.000        29.39     30.12         11.7          7      11.9
# ...           ...          ...       ...          ...        ...       ...
# 2939        0.000        29.42     30.07          8.5         29       9.0
# 2940        0.000        29.34     30.09          5.1         24       5.5
# 2941        0.005        29.41     30.10          5.9         23       6.5
# 2942        0.030        29.49     30.20         22.6         34      22.9
# 2943        0.040        29.54     30.20         21.7         34      22.6
#
#       Humidity
# 0           56
# 1           55
# 2           71
# 3           69
# 4           55
# ...        ...
# 2939        65
# 2940        73
# 2941        68
# 2942        55
# 2943        60
#
# [2944 rows x 23 columns]

# %%
weather["Humidity"].value_counts()
# Out:
# 59     116
# 62     113
# 60     107
# 65     102
# 56     100
# 58      98
# 64      97
# 69      95
# 55      93
# 67      93
# 68      90
# 52      89
# 61      88
# 57      87
# 66      87
# 71      85
# 53      85
# 74      80
# 63      80
# 54      80
# 50      67
# 76      64
# 51      61
# 73      59
# 47      59
# 48      50
# 49      48
# 70      45
# 72      44
# 78      44
# 75      42
# 81      39
# 46      39
# 84      35
# 79      34
# 43      31
# 45      27
# 77      27
# 44      25
# 87      24
# 80      22
# 83      22
# 41      21
# 90      18
# 42      18
# 40      16
# 93      14
# 86      14
# 39       9
# 82       9
# 38       9
# 89       8
# 37       7
# 35       5
# 85       5
# 32       3
# 36       3
# 34       3
# 96       2
# 33       2
# 30       1
# 102      1
# 104      1
# 100      1
# 107      1
# Name: Humidity, dtype: int64

# %%
weather["Sunrise"] = weather["Sunrise"].apply(pd.to_numeric)
weather["Sunset"] = weather["Sunset"].apply(pd.to_numeric)

# %% [markdown]
# #### Daylength
# Colder temperatures limit the reproduction of Culex mosquitoes and, along with shortening daylength, can induce some species to enter reproductive diapause. As a consequence, some mosquito-mediated arbovirus transmission declines to barely detectable levels during the winter season. [(source)](https://www.nature.com/articles/s41598-018-24133-4)
#
# Daylength is calculated using Sunset minus Sunrise.

# %%
weather["daylength"] = weather.apply(
    lambda row: daylength(row["Sunset"]) - daylength(row["Sunrise"]), axis=1
)

# %% [markdown]
# ### Merge Station 1 and 2

# %% [markdown]
# Weather station 1 and 2 values are vastly similar due to their close proximity, hence we will merge Station 1 and 2.

# %%
weather_2 = weather.groupby("Date").sum() / 2
weather_2 = weather_2.drop(columns=["Station"]).reset_index()

# %%
weather_2.head()
# Out:
#         Date       Tmax       Tmin       Tavg  Depart   DewPoint  WetBulb  \
# 0 2007-05-01  28.611111  10.555556  19.722222    14.0  10.555556     56.5
# 1 2007-05-02  15.277778   5.833333  10.833333    -3.0   5.555556     47.0
# 2 2007-05-03  19.166667   8.333333  13.888889     2.0   4.444444     49.0
# 3 2007-05-04  22.222222  10.000000  16.250000     4.0   5.277778     50.0
# 4 2007-05-05  18.888889  11.944444  15.555556     5.0   3.611111     49.5
#
#    Heat  Cool  Sunrise  Sunset  Depth  SnowFall  PrecipTotal  StnPressure  \
# 0   0.0   2.5    448.0  1849.0    0.0       0.0       0.0000       29.140
# 1  13.5   0.0    447.0  1850.0    0.0       0.0       0.0000       29.410
# 2   8.0   0.0    445.5  1851.0    0.0       0.0       0.0000       29.425
# 3   7.0   0.0    444.0  1852.0    0.0       0.0       0.0025       29.335
# 4   5.0   0.0    443.0  1853.0    0.0       0.0       0.0050       29.430
#
#    SeaLevel  ResultSpeed  ResultDir  AvgSpeed  Humidity  daylength
# 0    29.820         2.20       26.0      9.40      55.5      841.0
# 1    30.085        13.15        3.0     13.40      70.0      843.0
# 2    30.120        12.30        6.5     12.55      53.0      845.5
# 3    30.045        10.25        7.5     10.60      48.5      848.0
# 4    30.095        11.45        7.0     11.75      45.0      850.0

# %%
weather_2.shape
# Out:
# (1472, 21)

# %%
weather.shape
# Out:
# (2944, 24)

# %%
weather.head(40)
# Out:
#     Station       Date       Tmax       Tmin       Tavg  Depart   DewPoint  \
# 0         1 2007-05-01  28.333333  10.000000  19.444444      14  10.555556
# 1         2 2007-05-01  28.888889  11.111111  20.000000      14  10.555556
# 2         1 2007-05-02  15.000000   5.555556  10.555556      -3   5.555556
# 3         2 2007-05-02  15.555556   6.111111  11.111111      -3   5.555556
# 4         1 2007-05-03  18.888889   7.777778  13.333333       2   4.444444
# 5         2 2007-05-03  19.444444   8.888889  14.444444       2   4.444444
# 6         1 2007-05-04  18.888889   9.444444  14.444444       4   5.000000
# 7         2 2007-05-04  25.555556  10.555556  18.055556       4   5.555556
# 8         1 2007-05-05  18.888889  11.666667  15.555556       5   3.333333
# 9         2 2007-05-05  18.888889  12.222222  15.555556       5   3.888889
# 10        1 2007-05-06  20.000000   9.444444  15.000000       4  -1.111111
# 11        2 2007-05-06  20.000000  11.111111  15.555556       4  -1.111111
# 12        1 2007-05-07  28.333333   8.333333  18.333333      10   5.000000
# 13        2 2007-05-07  28.888889  10.000000  19.444444      10   3.888889
# 14        1 2007-05-08  27.777778  12.222222  20.000000      12  14.444444
# 15        2 2007-05-08  26.666667  15.555556  21.111111      12  13.888889
# 16        1 2007-05-09  25.000000  16.111111  20.555556      13  15.000000
# 17        2 2007-05-09  24.444444  17.222222  21.111111      13  15.555556
# 18        1 2007-05-10  28.888889  13.333333  21.111111      14  11.111111
# 19        2 2007-05-10  28.333333  15.000000  21.666667      14  11.111111
# 20        1 2007-05-11  21.111111  10.555556  16.111111       4   5.555556
# 21        2 2007-05-11  22.777778   9.444444  16.111111       4   6.666667
# 22        1 2007-05-12  17.777778   7.777778  12.777778      -2   2.222222
# 23        2 2007-05-12  18.333333   8.333333  13.333333      -2   2.777778
# 24        1 2007-05-13  20.555556   6.111111  13.333333      -2   0.555556
# 25        2 2007-05-13  20.555556   6.666667  13.888889      -2   0.000000
# 26        1 2007-05-14  32.222222  13.333333  22.777778      15   8.333333
# 27        2 2007-05-14  32.222222  12.222222  22.222222      15   7.222222
# 28        1 2007-05-15  26.666667  13.888889  20.555556      11  13.333333
# 29        2 2007-05-15  27.777778  13.333333  20.555556      11  13.333333
# 30        1 2007-05-16  18.888889   6.666667  12.777778      -4   6.111111
# 31        2 2007-05-16  17.777778   7.222222  12.777778      -4   5.555556
# 32        1 2007-05-17  16.666667   6.111111  11.666667      -6   0.000000
# 33        2 2007-05-17  16.111111   6.666667  11.666667      -6   0.000000
# 34        1 2007-05-18  21.666667   5.555556  13.888889      -3  -1.111111
# 35        2 2007-05-18  21.111111   6.111111  13.888889      -3  -0.555556
# 36        1 2007-05-19  26.666667  13.333333  20.000000       8   3.888889
# 37        2 2007-05-19  26.666667  13.333333  20.000000       8   2.777778
# 38        1 2007-05-20  20.555556   6.111111  13.333333      -5   4.444444
# 39        2 2007-05-20  20.555556   6.666667  13.888889      -5   5.000000
#
#     WetBulb  Heat  Cool  Sunrise  Sunset     CodeSum  Depth Water1  SnowFall  \
# 0        56     0     2      448    1849                  0      M       0.0
# 1        57     0     3      448    1849                  0      M       0.0
# 2        47    14     0      447    1850          BR      0      M       0.0
# 3        47    13     0      447    1850       BR HZ      0      M       0.0
# 4        48     9     0      446    1851                  0      M       0.0
# 5        50     7     0      445    1851          HZ      0      M       0.0
# 6        50     7     0      444    1852          RA      0      M       0.0
# 7        50     7     0      444    1852                  0      M       0.0
# 8        49     5     0      443    1853                  0      M       0.0
# 9        50     5     0      443    1853                  0      M       0.0
# 10       46     6     0      442    1855                  0      M       0.0
# 11       46     5     0      442    1854                  0      M       0.0
# 12       54     0     0      441    1856          RA      0      M       0.0
# 13       53     0     2      440    1855                  0      M       0.0
# 14       62     0     3      439    1857          BR      0      M       0.0
# 15       63     0     5      439    1856          HZ      0      M       0.0
# 16       63     0     4      438    1858       BR HZ      0      M       0.0
# 17       63     0     5      438    1858       BR HZ      0      M       0.0
# 18       60     0     5      437    1859          BR      0      M       0.0
# 19       61     0     6      437    1859       BR HZ      0      M       0.0
# 20       51     4     0      436    1860                  0      M       0.0
# 21       51     4     0      436    1900                  0      M       0.0
# 22       46    10     0      435    1901                  0      M       0.0
# 23       46     9     0      435    1901                  0      M       0.0
# 24       46     9     0      434    1902                  0      M       0.0
# 25       46     8     0      434    1902                  0      M       0.0
# 26       59     0     8      433    1903                  0      M       0.0
# 27       58     0     7      433    1903                  0      M       0.0
# 28       61     0     4      432    1904       RA BR      0      M       0.0
# 29       61     0     4      432    1904  TSRA RA BR      0      M       0.0
# 30       48    10     0      431    1905       RA BR      0      M       0.0
# 31       47    10     0      431    1905       RA BR      0      M       0.0
# 32       43    12     0      430    1906                  0      M       0.0
# 33       43    12     0      430    1906                  0      M       0.0
# 34       46     8     0      429    1907                  0      M       0.0
# 35       47     8     0      429    1907                  0      M       0.0
# 36       53     0     3      428    1908                  0      M       0.0
# 37       53     0     3      428    1908                  0      M       0.0
# 38       44     9     0      427    1909     RA VCTS      0      M       0.0
# 39       45     8     0      427    1909     TSRA RA      0      M       0.0
#
#     PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  AvgSpeed  \
# 0         0.000        29.10     29.82          1.7         27       9.2
# 1         0.000        29.18     29.82          2.7         25       9.6
# 2         0.000        29.38     30.09         13.0          4      13.4
# 3         0.000        29.44     30.08         13.3          2      13.4
# 4         0.000        29.39     30.12         11.7          7      11.9
# 5         0.000        29.46     30.12         12.9          6      13.2
# 6         0.005        29.31     30.05         10.4          8      10.8
# 7         0.000        29.36     30.04         10.1          7      10.4
# 8         0.005        29.40     30.10         11.7          7      12.0
# 9         0.005        29.46     30.09         11.2          7      11.5
# 10        0.000        29.57     30.29         14.4         11      15.0
# 11        0.000        29.62     30.28         13.8         10      14.5
# 12        0.005        29.38     30.12          8.6         18      10.5
# 13        0.000        29.44     30.12          8.5         17       9.9
# 14        0.000        29.29     30.03          2.7         11       5.8
# 15        0.005        29.36     30.02          2.5          8       5.4
# 16        0.130        29.21     29.94          3.9          9       6.2
# 17        0.020        29.28     29.93          3.9          7       5.9
# 18        0.000        29.20     29.92          0.7         17       4.1
# 19        0.000        29.26     29.91          2.0          9       3.9
# 20        0.000        29.33     30.04         11.3          3      12.9
# 21        0.000        29.39     30.03         11.7         36      12.8
# 22        0.000        29.49     30.20         12.4          3      12.9
# 23        0.000        29.54     30.19         12.7          1      13.0
# 24        0.000        29.49     30.24          6.6         14       8.1
# 25        0.000        29.55     30.24          6.4         11       7.6
# 26        0.000        29.23     29.97         16.9         21      17.3
# 27        0.000        29.31     29.98         14.1         21      14.6
# 28        0.380        29.13     29.84          8.1         27      12.3
# 29        0.600        29.19     29.83          8.1         25      10.8
# 30        0.140        29.33     30.03          7.8         36      12.2
# 31        0.070        29.39     30.03          8.0         36      11.8
# 32        0.000        29.55     30.27         10.5          3      11.3
# 33        0.000        29.62     30.27         11.7          1      12.2
# 34        0.000        29.53     30.25          5.4         25       7.5
# 35        0.000        29.60     30.26          3.4         22       5.5
# 36        0.000        29.34     30.08         11.1         24      11.4
# 37        0.000        29.41     30.08         11.1         23      11.4
# 38        0.070        29.38     30.11         10.4          4      10.7
# 39        0.110        29.44     30.11          8.6          3       9.7
#
#     Humidity  daylength
# 0         56        841
# 1         55        841
# 2         71        843
# 3         69        843
# 4         55        845
# 5         51        846
# 6         53        848
# 7         44        848
# 8         44        850
# 9         46        850
# 10        33        853
# 11        32        852
# 12        41        855
# 13        36        855
# 14        70        858
# 15        63        857
# 16        70        860
# 17        71        860
# 18        53        862
# 19        51        862
# 20        50        864
# 21        54        864
# 22        49        866
# 23        49        866
# 24        42        868
# 25        39        868
# 26        40        870
# 27        38        870
# 28        63        872
# 29        63        872
# 30        64        874
# 31        61        874
# 32        45        876
# 33        45        876
# 34        36        878
# 35        37        878
# 36        35        880
# 37        32        880
# 38        55        882
# 39        55        882

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2944 entries, 0 to 2943
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Station      2944 non-null   int64
#  1   Date         2944 non-null   datetime64[ns]
#  2   Tmax         2944 non-null   float64
#  3   Tmin         2944 non-null   float64
#  4   Tavg         2944 non-null   float64
#  5   Depart       2944 non-null   int64
#  6   DewPoint     2944 non-null   float64
#  7   WetBulb      2944 non-null   int64
#  8   Heat         2944 non-null   int64
#  9   Cool         2944 non-null   int64
#  10  Sunrise      2944 non-null   int64
#  11  Sunset       2944 non-null   int64
#  12  CodeSum      2944 non-null   object
#  13  Depth        2944 non-null   int64
#  14  Water1       2944 non-null   object
#  15  SnowFall     2944 non-null   float64
#  16  PrecipTotal  2944 non-null   float64
#  17  StnPressure  2944 non-null   float64
#  18  SeaLevel     2944 non-null   float64
#  19  ResultSpeed  2944 non-null   float64
#  20  ResultDir    2944 non-null   int64
#  21  AvgSpeed     2944 non-null   float64
#  22  Humidity     2944 non-null   int64
#  23  daylength    2944 non-null   int64
# dtypes: datetime64[ns](1), float64(10), int64(11), object(2)
# memory usage: 552.1+ KB

# %%
weather.head()
# Out:
#    Station       Date       Tmax       Tmin       Tavg  Depart   DewPoint  \
# 0        1 2007-05-01  28.333333  10.000000  19.444444      14  10.555556
# 1        2 2007-05-01  28.888889  11.111111  20.000000      14  10.555556
# 2        1 2007-05-02  15.000000   5.555556  10.555556      -3   5.555556
# 3        2 2007-05-02  15.555556   6.111111  11.111111      -3   5.555556
# 4        1 2007-05-03  18.888889   7.777778  13.333333       2   4.444444
#
#    WetBulb  Heat  Cool  Sunrise  Sunset CodeSum  Depth Water1  SnowFall  \
# 0       56     0     2      448    1849              0      M       0.0
# 1       57     0     3      448    1849              0      M       0.0
# 2       47    14     0      447    1850      BR      0      M       0.0
# 3       47    13     0      447    1850   BR HZ      0      M       0.0
# 4       48     9     0      446    1851              0      M       0.0
#
#    PrecipTotal  StnPressure  SeaLevel  ResultSpeed  ResultDir  AvgSpeed  \
# 0          0.0        29.10     29.82          1.7         27       9.2
# 1          0.0        29.18     29.82          2.7         25       9.6
# 2          0.0        29.38     30.09         13.0          4      13.4
# 3          0.0        29.44     30.08         13.3          2      13.4
# 4          0.0        29.39     30.12         11.7          7      11.9
#
#    Humidity  daylength
# 0        56        841
# 1        55        841
# 2        71        843
# 3        69        843
# 4        55        845

# %%
set(weather.columns) - set(weather_2.columns)
# Out:
# {'CodeSum', 'Station', 'Water1'}

# %%
temp = pd.Series([], name="CodeSum", dtype="str")
for i in range(0, len(weather), 2):
    temp[i / 2] = " ".join(
        set(weather.loc[i, "CodeSum"].split()).union(
            set(weather.loc[i + 1, "CodeSum"].split())
        )
    )

# %%
weather = weather_2.merge(temp, left_index=True, right_index=True)

# %% [markdown]
# #### Drop Columns
# We have decided to drop below columns:
# * Water1: same indicator as humidity
# * Depth: values are all 0, hence this feature will not be useful.
# * WetBulb: similar to Dewpoint but DewPoint is known to be more accurate.
# * CodeSum: CodeSum indicates weather conditions that are already recorded in other features including PrecipTotal and Snowfall
# * Heat: Tavg, which indicates the average temperature of each day is sufficient.
# * Cool: Tavg, which indicates the average temperature of each day is sufficient.
# * DewPoint: Dewpoint was used to engineer Relative Humidity, hence we will remove this to avoid multicollinearity
# * SnowFall: Snowfall recorded has values between 0 and 0.1, with most values recorded as 0.
# * Sunrise and Sunset: Daylength was created using Sunrise and Sunset, and will hence be removed.
# * Tmin and Tmax: Tavg will be used instead.

# %%
weather = weather.drop(
    columns=[
        "Depth",
        "WetBulb",
        "CodeSum",
        "Heat",
        "Cool",
        "DewPoint", 
        "SnowFall",
        "Tmin", 
        "Tmax",
        "Depart",
        "Sunrise", 
        "Sunset",
    ]
)

# %%
weather
# Out:
#            Date       Tavg  PrecipTotal  StnPressure  SeaLevel  ResultSpeed  \
# 0    2007-05-01  19.722222       0.0000       29.140    29.820         2.20
# 1    2007-05-02  10.833333       0.0000       29.410    30.085        13.15
# 2    2007-05-03  13.888889       0.0000       29.425    30.120        12.30
# 3    2007-05-04  16.250000       0.0025       29.335    30.045        10.25
# 4    2007-05-05  15.555556       0.0050       29.430    30.095        11.45
# ...         ...        ...          ...          ...       ...          ...
# 1467 2014-10-27  18.611111       0.0100       28.960    29.665        12.35
# 1468 2014-10-28  13.888889       0.0175       29.190    29.850        14.40
# 1469 2014-10-29   6.666667       0.0000       29.390    30.065         9.00
# 1470 2014-10-30   6.388889       0.0025       29.375    30.095         5.50
# 1471 2014-10-31   5.000000       0.0350       29.515    30.200        22.15
#
#       ResultDir  AvgSpeed  Humidity  daylength
# 0          26.0      9.40      55.5      841.0
# 1           3.0     13.40      70.0      843.0
# 2           6.5     12.55      53.0      845.5
# 3           7.5     10.60      48.5      848.0
# 4           7.0     11.75      45.0      850.0
# ...         ...       ...       ...        ...
# 1467       19.0     13.25      61.0      635.0
# 1468       26.0     15.10      51.0      632.5
# 1469       29.0      9.45      65.0      629.5
# 1470       23.5      6.00      70.5      627.0
# 1471       34.0     22.75      57.5      624.5
#
# [1472 rows x 10 columns]

# %% [markdown]
# Convert weather column names to lowercase

# %%
weather.columns = weather.columns.str.lower()

# %%
weather.head()
# Out:
#         date       tavg  preciptotal  stnpressure  sealevel  resultspeed  \
# 0 2007-05-01  19.722222       0.0000       29.140    29.820         2.20
# 1 2007-05-02  10.833333       0.0000       29.410    30.085        13.15
# 2 2007-05-03  13.888889       0.0000       29.425    30.120        12.30
# 3 2007-05-04  16.250000       0.0025       29.335    30.045        10.25
# 4 2007-05-05  15.555556       0.0050       29.430    30.095        11.45
#
#    resultdir  avgspeed  humidity  daylength
# 0       26.0      9.40      55.5      841.0
# 1        3.0     13.40      70.0      843.0
# 2        6.5     12.55      53.0      845.5
# 3        7.5     10.60      48.5      848.0
# 4        7.0     11.75      45.0      850.0

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# ## Spray
# Cleaning `spray.csv` dataset to make it consistent with the other datasets we will be using.

# %%
spray.shape
# Out:
# (14835, 4)

# %%
spray.dropna(inplace=True)

# also drop time column as this is not present in any other dataset
spray.drop(columns="Time", inplace=True)

# %%
spray.shape
# Out:
# (14251, 3)

# %%
cleaner(spray)
# Out:
# date          datetime64[ns]
# latitude             float64
# longitude            float64
# year                   int32
# weekofyear            UInt32
# dtype: object

# %%
spray.drop_duplicates(inplace=True)
spray.shape
# Out:
# (13710, 5)

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# ## Train

# %% [markdown]
# ### `Train` Dataframe

# %%
train.head()
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2  2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 3  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
# 4  2007-05-29    7900 West Foster Avenue, Chicago, IL 60656, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     62    N MANDELL AVE  T007
# 3  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE  T015
# 4          CULEX RESTUANS     79     W FOSTER AVE  T015
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 2   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279                9
# 3    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
# 4    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812                8
#
#    NumMosquitos  WnvPresent
# 0             1           0
# 1             1           0
# 2             1           0
# 3             1           0
# 4             4           0

# %%
train.shape
# Out:
# (10506, 12)

# %% [markdown]
# ### Cleaning for Train

# %% [markdown]
# #### NumMosquitos

# %% [markdown]
# This section checks the duplicate rows for mosquito count.
#
# In Kaggle, it is stated that each row has a maximum count of 50 rows. Anything more than 50 will be split into a different row.
#
# We will be aggregating these into the column 'nummosquitos'.

# %%
# check total mosquitoes in sample
train["NumMosquitos"].sum()
# Out:
# 135039

# %%
# duplicated rows with less than 50 mosquitoes
duplicates = train[(train.duplicated())]

duplicates["NumMosquitos"].sum()
# Out:
# 36068

# %%
# Prevent issue where one unique trap, species and date has 2 rows if wnv = 1 in one observation
# and 0 in another
train = (
    train.groupby(
        [col for col in train.columns if col not in ["NumMosquitos", "WnvPresent"]],
        as_index=False,
    )
    .sum()
    .reindex()
)


# Re-binarize wnvpresent column as it now has values more than 1
train["WnvPresent"] = train["WnvPresent"].map(lambda x: 1 if x > 0 else 0)

# %%
train["NumMosquitos"].sum()
# Out:
# 135039

# %%
train[train.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Address, Species, Block, Street, Trap, AddressNumberAndStreet, Latitude, Longitude, AddressAccuracy, NumMosquitos, WnvPresent]
# Index: []

# %% [markdown]
# #### Train dataframe
#
# Passing entire dataframe through the cleaner function to correct data types and convert all titles to lowercase.

# %%
# use cleaner function
cleaner(train)
# Out:
# date            datetime64[ns]
# species                 object
# trap                    object
# latitude               float64
# longitude              float64
# nummosquitos             int64
# wnvpresent               int64
# year                     int32
# weekofyear              UInt32
# dtype: object

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# #### Species

# %% [markdown]
# In this section, we first examine the distribution of mosquito species against them being carriers of the WNV.
#
# Only 3 species from the train data set seem to be carriers of the WNV:
# * Culex Pipens/Restuans
# * Culex Restuans
# * Culex Pipiens
#
# We then decided to group these in 2 main species groups -  1 for both culex pipiens/restuans and culex pipiens, 2 for culex restuans as we found that culex pipiens/restuans and culex pipiens have similar likelihoods of being WNV carriers.

# %%
# show total mozzies by species

plt.figure(figsize=(10, 7))
plot = sns.barplot(
    x="species", y="nummosquitos", hue="wnvpresent", data=train, estimator=sum
)
plt.xticks(rotation=90, fontsize=8)
plt.ylabel("Total Number of Mozzies", fontsize=14)
plt.xlabel("Species", fontsize=14)
plt.legend(loc="upper right", title="Virus")
plt.title("Mozzies by Species (2007-2013)", fontsize=20)
plt.show()

# %%
# Percentage of species with WNV

wnv_species = ["CULEX PIPIENS/RESTUANS", "CULEX PIPIENS", "CULEX RESTUANS"]

for i in wnv_species:
    percent = round(
        (
            (
                train[(train["wnvpresent"] == 1) & (train["species"] == str(i))][
                    "nummosquitos"
                ].sum()
            )
            / (train[train["species"] == str(i)]["nummosquitos"].sum())
            * 100
        ),
        2,
    )
    print(f"Percentage of {i} with west nile virus is: {percent}%")
# Out:
# Percentage of CULEX PIPIENS/RESTUANS with west nile virus is: 19.39%
# Percentage of CULEX PIPIENS with west nile virus is: 59.65%
# Percentage of CULEX RESTUANS with west nile virus is: 5.76%

# %%
# culex pipiens and culex pipiens/restuans are similar in terms of being carriers of the virus

# dummify these variables using a function

train["dum_species"] = train["species"].map(
    {"CULEX PIPIENS/RESTUANS": 1, "CULEX PIPIENS": 1, "CULEX RESTUANS": 2}
)

# 0 for species other than the virus carriers
train["dum_species"].fillna(0, inplace=True)

train["dum_species"] = train["dum_species"].astype("int64")

# %%
train.head()
# Out:
#         date                 species  trap   latitude  longitude  \
# 0 2007-05-29  CULEX PIPIENS/RESTUANS  T048  41.867108 -87.654224
# 1 2007-05-29          CULEX RESTUANS  T048  41.867108 -87.654224
# 2 2007-05-29          CULEX RESTUANS  T091  41.862292 -87.648860
# 3 2007-05-29          CULEX RESTUANS  T049  41.896282 -87.655232
# 4 2007-05-29          CULEX RESTUANS  T153  41.907645 -87.760886
#
#    nummosquitos  wnvpresent  year  weekofyear  dum_species
# 0             1           0  2007          22            1
# 1             2           0  2007          22            2
# 2             1           0  2007          22            2
# 3             1           0  2007          22            2
# 4             1           0  2007          22            2

# %% [markdown]
# #### Drop Columns
#
# * Trap (as it is already represented in latitude and longitude)

# %%
train.drop(columns="trap", inplace=True)

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# ## Test

# %% [markdown]
# To replicate the cleaning that has been done for the Train dataframe to ensure consistency when we use the data for modelling.

# %%
test.shape
# Out:
# (116293, 11)

# %%
cleaner(test)
# Out:
# id                     int64
# date          datetime64[ns]
# species               object
# trap                  object
# latitude             float64
# longitude            float64
# year                   int32
# weekofyear            UInt32
# dtype: object

# %%
test.head()
# Out:
#    id       date                 species  trap  latitude  longitude  year  \
# 0   1 2008-06-11  CULEX PIPIENS/RESTUANS  T002  41.95469 -87.800991  2008
# 1   2 2008-06-11          CULEX RESTUANS  T002  41.95469 -87.800991  2008
# 2   3 2008-06-11           CULEX PIPIENS  T002  41.95469 -87.800991  2008
# 3   4 2008-06-11        CULEX SALINARIUS  T002  41.95469 -87.800991  2008
# 4   5 2008-06-11         CULEX TERRITANS  T002  41.95469 -87.800991  2008
#
#    weekofyear
# 0          24
# 1          24
# 2          24
# 3          24
# 4          24

# %%
# create combined coordinates
test["latlong"] = test["latitude"].astype(str) + ", " + test["longitude"].astype(str)

# %%
# dummify species

test["dum_species"] = test["species"].map(
    {"CULEX PIPIENS/RESTUANS": 1, "CULEX PIPIENS": 1, "CULEX RESTUANS": 2}
)

# 0 for species other than the virus carriers
test["dum_species"].fillna(0, inplace=True)

test["dum_species"] = test["dum_species"].astype("int64")

# %%
# drop trap
test.drop(columns="trap", inplace=True)

# %%
test.head()
# Out:
#    id       date                 species  latitude  longitude  year  \
# 0   1 2008-06-11  CULEX PIPIENS/RESTUANS  41.95469 -87.800991  2008
# 1   2 2008-06-11          CULEX RESTUANS  41.95469 -87.800991  2008
# 2   3 2008-06-11           CULEX PIPIENS  41.95469 -87.800991  2008
# 3   4 2008-06-11        CULEX SALINARIUS  41.95469 -87.800991  2008
# 4   5 2008-06-11         CULEX TERRITANS  41.95469 -87.800991  2008
#
#    weekofyear               latlong  dum_species
# 0          24  41.95469, -87.800991            1
# 1          24  41.95469, -87.800991            2
# 2          24  41.95469, -87.800991            1
# 3          24  41.95469, -87.800991            0
# 4          24  41.95469, -87.800991            0

# %% [markdown]
# ## Combine Train/Test with Weather

# %% [markdown]
# In this section, we combine:
# 1) Train and Weather dataframes
# 2) Test and Weather dataframes
#
# In addition, we also created 4 features for lag of 2 weeks to "tavg", "humidity", "resultspeed", "preciptotal".
#
# In the EDA section (after this), we would be exploring these additional features we have created, and if it had an effect on mosquitoes and WNV.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8475 entries, 0 to 8474
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          8475 non-null   datetime64[ns]
#  1   species       8475 non-null   object
#  2   latitude      8475 non-null   float64
#  3   longitude     8475 non-null   float64
#  4   nummosquitos  8475 non-null   int64
#  5   wnvpresent    8475 non-null   int64
#  6   year          8475 non-null   int32
#  7   weekofyear    8475 non-null   UInt32
#  8   dum_species   8475 non-null   int64
# dtypes: UInt32(1), datetime64[ns](1), float64(2), int32(1), int64(3), object(1)
# memory usage: 862.2+ KB

# %%
# merge train dataset with weather
train = pd.merge(train, weather, on="date")
train.head()

train.rename(columns={"year_x": "year", "weekofyear_x": "weekofyear"}, inplace=True)

train.head()
# Out:
#         date                 species   latitude  longitude  nummosquitos  \
# 0 2007-05-29  CULEX PIPIENS/RESTUANS  41.867108 -87.654224             1
# 1 2007-05-29          CULEX RESTUANS  41.867108 -87.654224             2
# 2 2007-05-29          CULEX RESTUANS  41.862292 -87.648860             1
# 3 2007-05-29          CULEX RESTUANS  41.896282 -87.655232             1
# 4 2007-05-29          CULEX RESTUANS  41.907645 -87.760886             1
#
#    wnvpresent  year  weekofyear  dum_species       tavg  preciptotal  \
# 0           0  2007          22            1  24.166667          0.0
# 1           0  2007          22            2  24.166667          0.0
# 2           0  2007          22            2  24.166667          0.0
# 3           0  2007          22            2  24.166667          0.0
# 4           0  2007          22            2  24.166667          0.0
#
#    stnpressure  sealevel  resultspeed  resultdir  avgspeed  humidity  \
# 0       29.415      30.1          5.8       17.0      6.95      55.5
# 1       29.415      30.1          5.8       17.0      6.95      55.5
# 2       29.415      30.1          5.8       17.0      6.95      55.5
# 3       29.415      30.1          5.8       17.0      6.95      55.5
# 4       29.415      30.1          5.8       17.0      6.95      55.5
#
#    daylength
# 0      896.5
# 1      896.5
# 2      896.5
# 3      896.5
# 4      896.5

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8475 entries, 0 to 8474
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          8475 non-null   datetime64[ns]
#  1   species       8475 non-null   object
#  2   latitude      8475 non-null   float64
#  3   longitude     8475 non-null   float64
#  4   nummosquitos  8475 non-null   int64
#  5   wnvpresent    8475 non-null   int64
#  6   year          8475 non-null   int32
#  7   weekofyear    8475 non-null   UInt32
#  8   dum_species   8475 non-null   int64
#  9   tavg          8475 non-null   float64
#  10  preciptotal   8475 non-null   float64
#  11  stnpressure   8475 non-null   float64
#  12  sealevel      8475 non-null   float64
#  13  resultspeed   8475 non-null   float64
#  14  resultdir     8475 non-null   float64
#  15  avgspeed      8475 non-null   float64
#  16  humidity      8475 non-null   float64
#  17  daylength     8475 non-null   float64
# dtypes: UInt32(1), datetime64[ns](1), float64(11), int32(1), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
# merge test dataset with weather
test = pd.merge(test, weather, on="date")
test.head()

test.rename(columns={"year_x": "year", "weekofyear_x": "weekofyear"}, inplace=True)

test.head()
# Out:
#    id       date                 species  latitude  longitude  year  \
# 0   1 2008-06-11  CULEX PIPIENS/RESTUANS  41.95469 -87.800991  2008
# 1   2 2008-06-11          CULEX RESTUANS  41.95469 -87.800991  2008
# 2   3 2008-06-11           CULEX PIPIENS  41.95469 -87.800991  2008
# 3   4 2008-06-11        CULEX SALINARIUS  41.95469 -87.800991  2008
# 4   5 2008-06-11         CULEX TERRITANS  41.95469 -87.800991  2008
#
#    weekofyear               latlong  dum_species       tavg  preciptotal  \
# 0          24  41.95469, -87.800991            1  23.888889          0.0
# 1          24  41.95469, -87.800991            2  23.888889          0.0
# 2          24  41.95469, -87.800991            1  23.888889          0.0
# 3          24  41.95469, -87.800991            0  23.888889          0.0
# 4          24  41.95469, -87.800991            0  23.888889          0.0
#
#    stnpressure  sealevel  resultspeed  resultdir  avgspeed  humidity  \
# 0        29.31     29.98         9.15       18.0      10.2      50.5
# 1        29.31     29.98         9.15       18.0      10.2      50.5
# 2        29.31     29.98         9.15       18.0      10.2      50.5
# 3        29.31     29.98         9.15       18.0      10.2      50.5
# 4        29.31     29.98         9.15       18.0      10.2      50.5
#
#    daylength
# 0      910.0
# 1      910.0
# 2      910.0
# 3      910.0
# 4      910.0

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 116293 entries, 0 to 116292
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   id           116293 non-null  int64
#  1   date         116293 non-null  datetime64[ns]
#  2   species      116293 non-null  object
#  3   latitude     116293 non-null  float64
#  4   longitude    116293 non-null  float64
#  5   year         116293 non-null  int32
#  6   weekofyear   116293 non-null  UInt32
#  7   latlong      116293 non-null  object
#  8   dum_species  116293 non-null  int64
#  9   tavg         116293 non-null  float64
#  10  preciptotal  116293 non-null  float64
#  11  stnpressure  116293 non-null  float64
#  12  sealevel     116293 non-null  float64
#  13  resultspeed  116293 non-null  float64
#  14  resultdir    116293 non-null  float64
#  15  avgspeed     116293 non-null  float64
#  16  humidity     116293 non-null  float64
#  17  daylength    116293 non-null  float64
# dtypes: UInt32(1), datetime64[ns](1), float64(11), int32(1), int64(2), object(2)
# memory usage: 16.1+ MB

# %%
# adding lag of 2 weeks to weather data

# for train
for col in ["tavg", "humidity", "resultspeed", "preciptotal"]:
    train[(col + "_lag" + str(14))] = train[col].rolling(14, min_periods=1).mean()

for col in ["tavg", "humidity", "resultspeed", "preciptotal"]:
    test[(col + "_lag" + str(14))] = test[col].rolling(14, min_periods=1).mean()

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Information about mosquitoes
# Over the years, number of culex pipiens seem to have decreased, but increased again in 2013.
#
# There seems to be no effect of spraying on culex restuans, in fact the population has steadily increased over the years. Possible things to explore:
# 1) Did they develop a resistance to the sprays?
#
# 2) Were the areas where culex restuans found even sprayed at all?
#
# 3) Which areas were these found in? Did they have a different climate compared to the other species of mosquitoes?

# %%
# species by years

moz_year = train.groupby(["year", "species"], as_index=False).sum()

plt.figure(figsize=(16, 8))
plt.title("Number of Mozzies (by year)")
sns.barplot(x="year", y="nummosquitos", hue="species", data=moz_year)
plt.xlabel("Year")
plt.ylabel("Total Number of Mozzies")
# Out:
# Text(0, 0.5, 'Total Number of Mozzies')

# %%
plt.subplots(figsize=(20, 6))
month = train["date"].dt.month
year = train["date"].dt.year
plt.subplot(1, 2, 1)
ax1 = sns.barplot(x=month, y="nummosquitos", data=train, hue="wnvpresent")
ax1.set(xlabel="Month", ylabel="No. of Mosquitos")
plt.subplot(1, 2, 2)
ax2 = sns.barplot(x=year, y="nummosquitos", data=train, hue="wnvpresent")
ax2.set(xlabel="Year", ylabel="No. of Mosquitos")

# %% [markdown]
# ### Mosquitoes by area (to link this later)
#
# The plots for these can be found in the Maps notebook.

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# ### Spray vs mosquito population and WNV

# %% [markdown]
# In this section, we explore the effect of spraying on the total mosquito population, and whether WNV was present.
#
# As we only have 2 years of spray data (2011 and 2013), we only plotted the charts for these 2 years.

# %% [markdown]
# #### Spraying in 2011
#
# Spraying was only done twice, with little to no effect on WNV.
#
# For the first spray, total mosquito population decreased, but WNV was constant.
#
# After the 2nd spray, both mosquito population and WNV mosquitoes went up, suggesting that
# 1) the sprays are not effective, or
#
# 2) there could be other factors that increased mosquito breeding / propagation of WNV.

# %%
# when were sprays implemented

# Split the dataframe based on year
spray_df_2013 = spray[spray["date"].dt.year == 2013]
spray_df_2011 = spray[spray["date"].dt.year == 2011]

spray_2011 = spray_df_2011["date"].unique()[:2]
spray_2011

spray_2013 = spray_df_2013["date"].unique()[:8]
spray_2013

# %%
moz_2011 = train[train["date"].dt.year == 2011].groupby("date")["nummosquitos"].sum()
wnv_2011 = train[train["date"].dt.year == 2011].groupby("date")["wnvpresent"].sum()


fig, ax = plt.subplots(nrows=2, figsize=(15, 6))
ax[0].plot(moz_2011.index, moz_2011.values, color="black")
for date in spray_2011:
    ax[0].axvline(x=date, color="green", ls="-")
ax[0].set_title("total mosquitos 2011")
ax[0].legend(["mosquitos", "spray"], loc="upper right")


ax[1].plot(wnv_2011.index, wnv_2011.values, color="blue")
for date in spray_2011:
    ax[1].axvline(x=date, color="green", ls="-")
ax[1].set_title("wnv 2011")
ax[1].legend(["wnv", "spray"], loc="upper right")


plt.tight_layout()

# %% [markdown]
# #### Spraying in 2013
#
# For 2013, mosquitoes were sprayed mosquitoes extensively. It seemed to work in the beginning.
#
# However in mid-August, despite spraying the mosquito population (that had WNV) went up although total number of mosquitoes kind of remained constant. Could it be due to weather factors?

# %%
moz_2013 = train[train["date"].dt.year == 2013].groupby("date")["nummosquitos"].sum()
wnv_2013 = train[train["date"].dt.year == 2013].groupby("date")["wnvpresent"].sum()


fig, ax = plt.subplots(nrows=2, figsize=(15, 6))
ax[0].plot(moz_2013.index, moz_2013.values, color="black")
for date in spray_2013:
    ax[0].axvline(x=date, color="green", ls="-")
ax[0].set_title("total mosquitos 2013")
ax[0].legend(["mosquitos", "spray"], loc="upper right")


ax[1].plot(wnv_2013.index, wnv_2013.values, color="blue")
for date in spray_2013:
    ax[1].axvline(x=date, color="green", ls="-")
ax[1].set_title("wnv 2013")
ax[1].legend(["wnv", "spray"], loc="upper right")


plt.tight_layout()

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# ### Mozzies vs Weather

# %% [markdown]
# Observations with interactions from weather columns:
#
# 1) Likelihood of WNV is higher for culex pipiens+mixed breed with lower amount of rainfall. Similar results with lag, the optimal rainall for WNV seems to be 0-0.5mm for propagation of WNV.
#
# 2) Humidity between 55-80 seems like the best conditions for WNV in species 1
#
# 3) Regardless of temperature, culex pipiens+mixed breed still seem to propogate WNV, effects of temperature are more prominent for culex restuans (>25 deg more likely for WNV)
#
# 4) Optimal pressure for wnv propogation - between 29-29.5
#
# 5) Daylength and Resultant speed seem like pretty useless features - mosquitos propogate WNV regardless - esp for pipiens+mixed breed
#
# 6) WNV more prevalent in weeks 28-37 (but why?)

# %%
# function to plot relationship
def chart(dataset, weather_col, color):
    sns.relplot(
        x=weather_col,
        y="nummosquitos",
        hue="wnvpresent",
        col="dum_species",
        data=dataset,
        palette=["lightgrey", color],
        s=100,
        alpha=0.5,
    )

# %%
# wet weather columns
chart(train, "preciptotal", "orange")
chart(train, "preciptotal_lag14", "orange")

chart(train, "humidity", "blue")
chart(train, "humidity_lag14", "blue")

# %%
# temperature variables

chart(train, "tavg", "red")
chart(train, "tavg_lag14", "red")

# presure and wind
chart(train, "stnpressure", "purple")
chart(train, "resultspeed", "green")

# %%
# duration variables

chart(train, "daylength", "blue")
chart(train, "weekofyear", "red")

# %%
plt.figure(figsize=(10, 6))
X = train[train["wnvpresent"] == 1]
ax = sns.countplot(x="weekofyear", data=X)
ax.set_title("No. of Mosquitos where WNV is Present (Week of Year)")
ax.set_xlabel("Week of Year")
ax.set_ylabel("No. of Mosquitos")

# %% [markdown]
# [Back to top](#Organization)

# %% [markdown]
# ### Heatmaps and Correlation

# %%
# Preliminary heatmap.

# could give us an indication of what features to drop - multicollinear

plt.figure(figsize=(20, 10))

corr = train.corr()


matrix = np.triu(corr)
sns.heatmap(
    corr,
    annot=True,
    mask=matrix,
    vmin=-1,
    vmax=1,
    cmap=(sns.diverging_palette(220, 20, as_cmap='coolwarm')),
)

plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.heatmap(
    train.corr()[["wnvpresent"]].sort_values("wnvpresent", ascending=False),
    annot=True,
    cmap="coolwarm",
    vmin=-1,
    vmax=1,
);

# %% [markdown]
# ## Feature Engineering

# %%
train["weekofyear"].value_counts().sort_values()

# %%
train = dum_wkyr(train)

# %%
test = dum_wkyr(test)

# %% [markdown]
# ## Saving dataframes for modelling

# %%
train.to_csv("../datasets/final_train.csv", index=False)
test.to_csv("../datasets/final_test.csv", index=False)

# %% [markdown]
# [Back to top](#Organization)

# %%
train.info()
