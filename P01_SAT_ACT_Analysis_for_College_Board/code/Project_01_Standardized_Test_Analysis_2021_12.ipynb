# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis
# ---

# %% [markdown]
# <font color = '#808080' size = 2> <b> Part 1 </b>: Part 1 requires knowledge of basic Python. </font> <br>
#
# ## Executive Summary
#
# Our team of consulting interns have analysed past year data cross-state data in the United States from 2017 to 2019. This analysis takes datasets of participation rates and total/composite scores for the SAT and the ACT across states and years 2017 to 2019.
#
# With the ACT being the main competing standardized test with high take-up rate across states, we find there are useful insights relevant to examining marketing strategies to boost SAT participation rates. **Test participation is an important profitability-linked metric because it builds College Board's student database. This in turn drives revenue generation linked to leasing such data to colleges and scholarship programs.**
#
# **Pennsylvania, Vermont, and Virgina seem to be promising targets for College Board to double up efforts to grow participation rates.** We see them as "low hanging fruit" since 10% of 2019 potential test-takers did not take either the ACT or the SAT, and there are over 50% of 2019 test-takers already favouring the SAT. Peer group targeting may make for a good campaign strategy here.
#
# More generally, we also believe that three-pronged strategy that includes (1) **growing** overall participation rate in states with less than 90% test participation rates, (2) **defending** existing market share, and (3) **repeating past successes** (converting states from ACT to SAT).
#
# Also, the College Board should be aware of concerns about the progressiveness of standardized tests. Various news sources have reported that colleges are starting to drop standardized testing requirements for admissions. This is one of the reasons why California was not proposed as a state to be targeted even though it does fit into a similar category as Pennsylvaina, Vermont and Virginia based on existing participation rate trends.

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ***
# The College Board needs advice on campaign budgeting and investments to be made towards each state in the United States.
# <br>
#
# **Tracking statewide participation, recommend which state(s) should be prioritized to boost SAT participation rates.**
# ***

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)

# %% [markdown]
# <b> Note: </b> <br>
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# > More background information is captured in later segments, especially under the "Outside Research" segment.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# ---
# **Used datasets**: 2017-19 ACT and SAT Scores by State, which includes state participation rates (6 datasets)
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# ---

# %% [markdown]
# ### Outside Research

# %% [markdown]
# <font color = '#808080'> Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**
# </font>

# %% [markdown]
# **Scoring ranges per test:**
# 1. ACT range: 1 to 36 (composite score, from 4 compulsory sections (the writing section is optional), taken via a percentile approach against a general population; follows normal distribution <br>
# <i> For more details: https://blog.prepscholar.com/what-is-a-good-act-score-a-bad-act-score-an-excellent-act-score
#     </i><br>
# <br>
# 2. SAT range: 400 to 1600 (2 sections of range 200 to 800 each); follows normal distribution <br>
# <i> For more details: https://blog.prepscholar.com/what-is-a-good-sat-score-a-bad-sat-score-an-excellent-sat-score
#     </i>
#
# **On state requirements and related policy towards the ACT / SAT test:**
# 1. Standardized testing is mandatory by state policy in some states. <br>
# <i> For more details: https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
#     </i><br>
#     <br>
# 2. The College Board introduced the SAT School Day in 2010 to increase access to the SAT, although it did not gain much traction (3 states offered to juniors in 2014-15 school year). Today, however, with a revamp of the SAT assessment in 2016, we see a total of 20 states (plus Washington, DC) offering free SATs to all high school juniors in public schools. This, and point 1, impact College Board's strategy in relation to states to target.<br>
# <i> For more details: https://blog.prepscholar.com/which-states-require-the-sat
#     </i><br>
#     <br>
# 3. There was a redesign of the SAT released in 2016. Whereas previously the SAT was seen as an aptitude test (rather than a knowledge test), this change made the SAT more appealing for usage as an assessment test than before.<br>
# <i> For more details: https://www.theatlantic.com/education/archive/2015/06/should-the-sat-be-part-of-school/395417/
#     </i><br>
#     <br>
#
# **Understanding the "business" of College Board**<br>
#
# College Board's tests (PSAT, SAT exams) are "loss leaders". The profit engine is actually their student database. This is under their "College and Career Opportunities & Enrollment" division, and based on Forbes (2020; source quoted below), they generated "more than $100 million in revenue with gross margins of 41%" in 2018.
#
# The way this works is based on an opt-in process (requested during the test, and with the option of opting in online at any time) where College Board is then given permission to share student names and some limited data with colleges and scholarship programs.
#
# Since test participation is an opportunity to get students to opt in, and thereby add to the College Board student database, test participation rates per state per year would be reasonably linked to overall profitability at the organization at large.
#
# <i> Source: https://www.forbes.com/sites/susanadams/2020/09/30/the-forbes-investigation-how-the-sat-failed-america/?sh=78a4e71653b5
#     </i><br>
#     <br>
#
# **More about College Board:**<br>
# <font color = '#606060'>
# "College Board is a mission-driven not-for-profit organization that connects students to college success and opportunity. Founded in 1900, College Board was created to expand access to higher education. Today, the membership association is made up of over 6,000 of the world’s leading educational institutions and is dedicated to promoting excellence and equity in education. Each year, College Board helps more than seven million students prepare for a successful transition to college through programs and services in college readiness and college success—including the SAT, the Advanced Placement Program, and BigFuture. The organization also serves the education community through research and advocacy on behalf of students, educators, and schools." </font>
# <br><br>
# *The above is quoted from the College Board website. For more details: https://about.collegeboard.org/*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
test_list = list(range(0,101))

def get_mean(data):
    return sum(data) / len(data)

get_mean(test_list)

# test correctness
# import numpy as np
# get_mean(test_list) == np.mean(test_list)
# Out:
# 50.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def get_sd(test_list):
    
    total = 0
    
    for num in test_list:
        pop_mean = get_mean(test_list)
        difference = (num - pop_mean) ** 2
        total += difference
        
    return (( 1 / len(test_list) ) * total ) ** 0.5
    
get_sd(test_list)

# test correctness
# import numpy as np
# get_sd(test_list) == np.std(test_list)
# Out:
# 29.154759474226502

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:

def pct_str_to_float(pct_string):
    
    if '%' in pct_string:
        return float(pct_string[:-1]) / 100
    
    else:
        return pct_string + 'Check'

pct_str_to_float('30.5%')

# test for correctness
# type(pct_str_to_float('30.5%'))
# Out:
# 0.305

# %% [markdown]
# ---
# <font color = '#808080' size = 2> <b> Part 2 </b>: Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization. </font> <br>
# ***

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Datasets:

df_act_2017 = pd.read_csv('../data/act_2017.csv')
df_act_2017.name = "2017 ACT Scores by State"
df_act_2018 = pd.read_csv('../data/act_2018.csv')
df_act_2018.name = "2018 ACT Scores by State"
df_act_2019 = pd.read_csv('../data/act_2019.csv')
df_act_2019.name = "2019 ACT Scores by State"

df_sat_2017 = pd.read_csv('../data/sat_2017.csv')
df_sat_2017.name = "2017 SAT Scores by State"
df_sat_2018 = pd.read_csv('../data/sat_2018.csv')
df_sat_2018.name = "2018 SAT Scores by State"
df_sat_2019 = pd.read_csv('../data/sat_2019.csv')
df_sat_2019.name = "2019 SAT Scores by State"


# Add below when needed:

# df_act_2019_ca = pd.read_csv('../data/act_2019_ca.csv')
# df_sat_2019_ca = pd.read_csv('../data/sat_2019_ca.csv')
# df_sat_2019_college = pd.read_csv('../data/sat_2019_by_intended_college_major.csv')
# df_sat_2019_college.name = "2019 SAT Scores by Intended College Major"
# df_both_college = pd.read_csv('../data/sat_act_by_college.csv')
# df_both_college.name = "Ranges of Accepted ACT & SAT Student Scores by Colleges"

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# #### 1. Display data:
# Showing first 5 rows of each dataframe.

# %%
# Code:
display('First 5 rows of each dataframe:',
        '-------------------------------',
        df_act_2017.name,
        df_act_2017.head(5), 
        df_act_2018.name,
        df_act_2018.head(5), 
        df_act_2019.name,
        df_act_2019.head(5), 
        df_sat_2017.name,
        df_sat_2017.head(5),
        df_sat_2018.name,
        df_sat_2018.head(5),
        df_sat_2019.name,
        df_sat_2019.head(5)
       )
# Out:
# 'First 5 rows of each dataframe:'
# '-------------------------------'
# '2017 ACT Scores by State'
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4
# '2018 ACT Scores by State'
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
# '2019 ACT Scores by State'
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# ...

# %% [markdown]
# #### 2. Check for missing values
# Here, analysis assumes null values are missing values. Display findings per df.

# %%
display(
    'Missing values (isnull) summary per df:',
    '---------------------------------------',
    df_act_2017.name,
    df_act_2017.isna().sum(), 
    df_act_2018.name,
    df_act_2018.isna().sum(), 
    df_act_2019.name,
    df_act_2019.isna().sum(), 
    df_sat_2017.name,
    df_sat_2017.isna().sum(),
    df_sat_2018.name,
    df_sat_2018.isna().sum(),
    df_sat_2019.name,
    df_sat_2019.isna().sum(), 
)
# Out:
# 'Missing values (isnull) summary per df:'
# '---------------------------------------'
# '2017 ACT Scores by State'
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64
# '2018 ACT Scores by State'
# State            0
# Participation    0
# Composite        0
# dtype: int64
# '2019 ACT Scores by State'
# State            0
# Participation    0
# Composite        0
# dtype: int64
# '2017 SAT Scores by State'
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
# '2018 SAT Scores by State'
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# ...

# %% [markdown]
# > There are no missing values in the datasets for ACT scores and SAT scores. <br>

# %% [markdown]
# #### 3. Checking for obvious issues with observations
# 1. Describe data and review min/max known ranges, dtypes (next section).
# 2. Validating scores (min, max) based on SAT, ACT norms, and that totals are sensible (while allowing for some rounding error).
# 3. Participation rates should be between 0% to 100%. (requires conversion; review in next section)

# %%
# describe all for each dataset
display(
    'Min / max values in each df:',
    '--------------------',
    df_act_2017.name,
    df_act_2017.describe(include = 'all'), # science score of 2.3 seems wrong
    df_sat_2017.name,
    df_sat_2017.describe(include = 'all'), # math score of 52 seems wrong
    df_act_2018.name,
    df_act_2018.describe(include = 'all'), 
    df_sat_2018.name,
    df_sat_2018.describe(include = 'all'),
    df_act_2019.name,
    df_act_2019.describe(include = 'all'), 
    df_sat_2019.name,
    df_sat_2019.describe(include = 'all')
)
# Out:
# 'Min / max values in each df:'
# '--------------------'
# '2017 ACT Scores by State'
#          State Participation    English       Math    Reading    Science  \
# count       52            52  52.000000  52.000000  52.000000  52.000000
# unique      52            28        NaN        NaN        NaN        NaN
# top     Hawaii          100%        NaN        NaN        NaN        NaN
# freq         1            17        NaN        NaN        NaN        NaN
# mean       NaN           NaN  20.919231  21.173077  22.001923  21.040385
# std        NaN           NaN   2.332132   1.963602   2.048672   3.151113
# min        NaN           NaN  16.300000  18.000000  18.100000   2.300000
# 25%        NaN           NaN  19.000000  19.400000  20.475000  19.900000
# 50%        NaN           NaN  20.550000  20.900000  21.700000  21.150000
# 75%        NaN           NaN  23.300000  23.100000  24.125000  22.525000
# max        NaN           NaN  25.500000  25.300000  26.000000  24.900000
#
# ...

# %% [markdown]
# > Across datasets, looks like participation rates were not in the right format to get statistics on.
# >
# > For 2017 datasets, the ACT composite score description did not show mean / min / max values. Digging deeper, there was both a dtype issue and a string value error in the last row (see below). Also, 2017 ACT science score looks unnaturally low (although possible), and 2017 SAT math score was impossible based on possible scoring range of 200 to 800. These need to be cleaned.

# %%
# When checking: df_act_2017['Composite'].astype(float)
# Error message shows there is a value of '20.2x' which cannot be converted to float

# Last row as the issue, tested with code below:
# df_act_2017['Composite'] == '20.2x'

df_act_2017['Composite'][0:51].astype(float).describe() # likely only dtype issue was remaining for other cells
# Out:
# count    51.000000
# mean     21.535294
# std       2.013338
# min      17.800000
# 25%      19.800000
# 50%      21.400000
# 75%      23.600000
# max      25.500000
# Name: Composite, dtype: float64

# %%
# Code:
display(
    'Checks on min/max/totals per df:',
    '--------------------------------',
    df_sat_2017.name,
    df_sat_2017[
        (df_sat_2017['Evidence-Based Reading and Writing'] > 800) 
        | (df_sat_2017['Evidence-Based Reading and Writing'] < 200)
        | (df_sat_2017['Math'] > 800)
        | (df_sat_2017['Math'] < 200)
        | ((df_sat_2017['Total'] - df_sat_2017['Math'] - df_sat_2017['Evidence-Based Reading and Writing']) > 1.01)
        | ((df_sat_2017['Total'] - df_sat_2017['Math'] - df_sat_2017['Evidence-Based Reading and Writing']) < -1.01)
    ], 
    df_act_2018.name,
    df_act_2018[(df_act_2018['Composite'] > 36) | (df_act_2018['Composite'] < 1)],
    df_sat_2018.name,
    df_sat_2018[
        (df_sat_2018['Evidence-Based Reading and Writing'] > 800) 
        | (df_sat_2018['Evidence-Based Reading and Writing'] < 200)
        | (df_sat_2018['Math'] > 800)
        | (df_sat_2018['Math'] < 200)
        | ((df_sat_2018['Total'] - df_sat_2018['Math'] - df_sat_2018['Evidence-Based Reading and Writing']) > 1.01)
        | ((df_sat_2018['Total'] - df_sat_2018['Math'] - df_sat_2018['Evidence-Based Reading and Writing']) < -1.01)
    ], 
    df_act_2019.name,
    df_act_2019[(df_act_2019['Composite'] > 36) | (df_act_2019['Composite'] < 1)],
    df_sat_2019.name,
    df_sat_2019[
        (df_sat_2019['EBRW'] > 800) 
        | (df_sat_2019['EBRW'] < 200)
        | (df_sat_2019['Math'] > 800)
        | (df_sat_2019['Math'] < 200)
        | ((df_sat_2019['Total'] - df_sat_2019['Math'] - df_sat_2019['EBRW']) > 1.01)
        | ((df_sat_2019['Total'] - df_sat_2019['Math'] - df_sat_2019['EBRW']) < -1.01)
    ]
)
# Out:
# 'Checks on min/max/totals per df:'
# '--------------------------------'
# '2017 SAT Scores by State'
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060
# '2018 ACT Scores by State'
# Empty DataFrame
# Columns: [State, Participation, Composite]
# Index: []
# '2018 SAT Scores by State'
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total]
# Index: []
# '2019 ACT Scores by State'
# Empty DataFrame
# Columns: [State, Participation, Composite]
# Index: []
# '2019 SAT Scores by State'
# Empty DataFrame
# Columns: [State, Participation Rate, EBRW, Math, Total]
# Index: []

# %% [markdown]
# #### 4. Fix issues in steps 2 and 3.

# %%
# Issue 1: '20.2x' in last row of df_act_2017's Composite column
# View issue
df_act_2017.loc[df_act_2017['Composite'] == '20.2x']
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
df_act_2017['Composite'] = df_act_2017['Composite'].replace('20.2x', 20.2)

# %%
# Validation that issue is resolved
df_act_2017.loc[51]
# Out:
# State            Wyoming
# Participation       100%
# English             19.4
# Math                19.8
# Reading             20.8
# Science             20.6
# Composite           20.2
# Name: 51, dtype: object

# %%
# Issue 2: Math score in df_sat_2017
# View issue
df_sat_2017[df_sat_2017['Math'] == 52]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
# Value should not be 52, but 524.
# Source: https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/
df_sat_2017['Math'] = df_sat_2017['Math'].replace(52, 524)

# %%
df_sat_2017.loc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                       524
# Total                                     1060
# Name: 20, dtype: object

# %%
# Issue 3: Science score in df_act_2017
# View issue
df_act_2017.loc[df_act_2017['Science'] == 2.3]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
# 2.3 should actually be 23.2; set value
# Source: https://www.act.org/content/dam/act/unsecured/documents/cccr2018/Maryland-CCCR-2018.pdf
df_act_2017['Science'] = df_act_2017['Science'].replace(2.3, 23.2)

# %%
# Validation that issue is resolved
df_act_2017.loc[21]
# Out:
# State            Maryland
# Participation         28%
# English              23.3
# Math                 23.1
# Reading              24.2
# Science              23.2
# Composite            23.6
# Name: 21, dtype: object

# %% [markdown]
# #### 5. Display dtypes.

# %%
display(
    'Datatypes in each df:',
    '--------------------',
    df_act_2017.name,
    df_act_2017.dtypes, 
    df_sat_2017.name,
    df_sat_2017.dtypes, 
    df_act_2018.name,
    df_act_2018.dtypes, 
    df_sat_2018.name,
    df_sat_2018.dtypes, 
    df_act_2019.name,
    df_act_2019.dtypes, 
    df_sat_2019.name,
    df_sat_2019.dtypes
)
# Out:
# 'Datatypes in each df:'
# '--------------------'
# '2017 ACT Scores by State'
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object
# '2017 SAT Scores by State'
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
# '2018 ACT Scores by State'
# State             object
# Participation     object
# Composite        float64
# dtype: object
# '2018 SAT Scores by State'
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
# '2019 ACT Scores by State'
# ...

# %% [markdown]
# > 1. 2017 ACT 'Composite' should be float.
# > 2. Across datasets, participation rate needs clean up and should be floats (e.g. 1% = 0.01).
# > 3. Across datasets, state names should be strings.

# %% [markdown]
# #### 6. Fix issues in step 5.

# %%
# Issue 1: 2017 ACT 'Composite' should be float.
df_act_2017['Composite'] = df_act_2017['Composite'].astype(float)

# %%
df_act_2017['Composite'].dtype
# Out:
# dtype('float64')

# %%
# Issue 2: Across datasets, participation rate needs clean up and change to float.
df_act_2017['Participation'] = df_act_2017['Participation'].apply(pct_str_to_float)
df_act_2018['Participation'] = df_act_2018['Participation'].apply(pct_str_to_float)
df_act_2019['Participation'] = df_act_2019['Participation'].apply(pct_str_to_float)
df_sat_2017['Participation'] = df_sat_2017['Participation'].apply(pct_str_to_float)
df_sat_2018['Participation'] = df_sat_2018['Participation'].apply(pct_str_to_float)
df_sat_2019['Participation Rate'] = df_sat_2019['Participation Rate'].apply(pct_str_to_float)

# %%
display(
    df_act_2017['Participation'].dtype,
    df_act_2018['Participation'].dtype,
    df_act_2019['Participation'].dtype,
    df_sat_2017['Participation'].dtype,
    df_sat_2018['Participation'].dtype,
    df_sat_2019['Participation Rate'].dtype
)
# Out:
# dtype('float64')
# dtype('float64')
# dtype('float64')
# dtype('float64')
# dtype('float64')
# dtype('O')

# %%
df_sat_2019['Participation Rate']
# Out:
# 0       0.07
# 1       0.41
# 2       0.31
# 3       0.06
# 4       0.63
# 5        1.0
# 6        1.0
# 7        1.0
# 8       0.94
# 9        1.0
# 10      0.71
# 11      0.54
# 12       1.0
# 13       1.0
# 14      0.66
# 15      0.03
# 16      0.04
# 17      0.04
# 18      0.05
# 19      0.99
# 20      0.82
# 21      0.81
# 22       1.0
# 23      0.04
# 24      0.03
# 25      0.04
# 26      0.09
# 27      0.03
# 28       0.2
# 29      0.95
# 30      0.82
# 31      0.18
# 32      0.79
# 33      0.51
# 34      0.02
# 35      0.19
# 36      0.22
# 37      0.51
# 38       0.7
# 39    —Check
# 40       1.0
# 41      0.68
# 42      0.03
# 43      0.07
# 44      0.68
# 45      0.04
# 46      0.66
# 47    —Check
# 48      0.68
# 49       0.7
# 50      0.99
# 51      0.03
# 52      0.03
# Name: Participation Rate, dtype: object

# %%
# Dash values occurred for Puerto Rico and Virgin Islands.
# Drop lines as we are unable to get use-able estimates for participation rate.
# 2019: 5,189 test takers in Puerto Rico; 656 test takers in Virgin Islands --> cannot establish suitable denominator
# Additional source for 2019: https://reports.collegeboard.org/archive/sat-suite-program-results/2019/state-results

df_sat_2019.drop(
    df_sat_2019[
        (df_sat_2019['State'] == 'Puerto Rico') 
        | (df_sat_2019['State'] == 'Virgin Islands')
    ].index, inplace = True
)

# %%
df_sat_2019['Participation Rate'] = df_sat_2019['Participation Rate'].astype(float)

# %%
df_sat_2019['Participation Rate'].dtype
# Out:
# dtype('float64')

# %%
# Issue 3: State names should be strings.
# Setting state names as strings

def set_col_as_str(col_name, df_name):
    df_name[col_name] = df_name[col_name].astype('string')
    print (f'{df_name.name} {[col_name]} dtype : {df_name[col_name].dtype}')
    
set_col_as_str('State', df_act_2017)
set_col_as_str('State', df_act_2018)
set_col_as_str('State', df_act_2019)
set_col_as_str('State', df_sat_2017)
set_col_as_str('State', df_sat_2018)
set_col_as_str('State', df_sat_2019)
# Out:
# 2017 ACT Scores by State ['State'] dtype : string
# 2018 ACT Scores by State ['State'] dtype : string
# 2019 ACT Scores by State ['State'] dtype : string
# 2017 SAT Scores by State ['State'] dtype : string
# 2018 SAT Scores by State ['State'] dtype : string
# 2019 SAT Scores by State ['State'] dtype : string

# %%
# DC caps issue; noticed from shape of data during merging

df_act_2018['State'] = df_act_2018['State'].replace('District of columbia','District of Columbia')

# %% [markdown]
# **7. Rename Columns**

# %%
# Column names should be all lowercase.
df_act_2017.columns = map(str.lower, df_act_2017.columns)
df_act_2018.columns = map(str.lower, df_act_2018.columns)
df_act_2019.columns = map(str.lower, df_act_2019.columns)
df_sat_2017.columns = map(str.lower, df_sat_2017.columns)
df_sat_2018.columns = map(str.lower, df_sat_2018.columns)
df_sat_2019.columns = map(str.lower, df_sat_2019.columns)

# %%
# Column names should not contain spaces 
# (underscores will suffice--
#  this allows for using the df.column_name method to access columns in addition to df['column_name']).

def space_to_underscore(string_with_space):
    return string_with_space.replace(' ','_')

df_act_2017.columns = map(space_to_underscore, df_act_2017.columns)
df_act_2018.columns = map(space_to_underscore, df_act_2018.columns)
df_act_2019.columns = map(space_to_underscore, df_act_2019.columns)
df_sat_2017.columns = map(space_to_underscore, df_sat_2017.columns)
df_sat_2018.columns = map(space_to_underscore, df_sat_2018.columns)
df_sat_2019.columns = map(space_to_underscore, df_sat_2019.columns)

# %%
# Column names should be unique and informative.
# ebrw should suffice as an abbreviation of evidence-based_reading_and_writing

def ebrw_tfm(string_with_space):
    return string_with_space.replace('evidence-based_reading_and_writing','ebrw')

df_sat_2017.columns = map(ebrw_tfm, df_sat_2017.columns)
df_sat_2018.columns = map(ebrw_tfm, df_sat_2018.columns)

# %%
# participation should suffice as an abbreviation of participation rate

df_sat_2019.columns = map(lambda x: x.replace('participation_rate', 'participation'), df_sat_2019.columns)

# %%
# unique column names for participation
df_act_2017.columns = map(lambda x: x.replace('participation', 'participation_act_2017'), df_act_2017.columns)
df_act_2018.columns = map(lambda x: x.replace('participation', 'participation_act_2018'), df_act_2018.columns)
df_act_2019.columns = map(lambda x: x.replace('participation', 'participation_act_2019'), df_act_2019.columns)
df_sat_2017.columns = map(lambda x: x.replace('participation', 'participation_sat_2017'), df_sat_2017.columns)
df_sat_2018.columns = map(lambda x: x.replace('participation', 'participation_sat_2018'), df_sat_2018.columns)
df_sat_2019.columns = map(lambda x: x.replace('participation', 'participation_sat_2019'), df_sat_2019.columns)

# unique column names for totals; rename composite to total for easy sorting / reading
df_act_2017.columns = map(lambda x: x.replace('composite', 'total_act_2017'), df_act_2017.columns)
df_act_2018.columns = map(lambda x: x.replace('composite', 'total_act_2018'), df_act_2018.columns)
df_act_2019.columns = map(lambda x: x.replace('composite', 'total_act_2019'), df_act_2019.columns)
df_sat_2017.columns = map(lambda x: x.replace('total', 'total_sat_2017'), df_sat_2017.columns)
df_sat_2018.columns = map(lambda x: x.replace('total', 'total_sat_2018'), df_sat_2018.columns)
df_sat_2019.columns = map(lambda x: x.replace('total', 'total_sat_2019'), df_sat_2019.columns)

# %%
# valdiate column headers
# sat ebrw and math headers left; total scores will be the focus, not the subscores

display(
    df_act_2017.head(0),
    df_act_2018.head(0),
    df_act_2019.head(0),
    df_sat_2017.head(0),
    df_sat_2018.head(0),
    df_sat_2019.head(0)
)
# Out:
# Empty DataFrame
# Columns: [state, participation_act_2017, english, math, reading, science, total_act_2017]
# Index: []
# Empty DataFrame
# Columns: [state, participation_act_2018, total_act_2018]
# Index: []
# Empty DataFrame
# Columns: [state, participation_act_2019, total_act_2019]
# Index: []
# Empty DataFrame
# Columns: [state, participation_sat_2017, ebrw, math, total_sat_2017]
# Index: []
# Empty DataFrame
# Columns: [state, participation_sat_2018, ebrw, math, total_sat_2018]
# Index: []
# Empty DataFrame
# Columns: [state, participation_sat_2019, ebrw, math, total_sat_2019]
# Index: []

# %% [markdown]
# **8. Drop unnecessary rows (if needed).**

# %%
# Drop all Puerto Rico and Virgin Islands rows for consistency with 2019 dataset.

def drop_pr_vi(df_name):
    df_name.drop(
        df_name[
            (df_name['state'] == 'Puerto Rico') 
            | (df_name['state'] == 'Virgin Islands')
        ].index, inplace = True
    )

dataset_raw = [
    df_act_2017,
    df_act_2018,
    df_act_2019,
    df_sat_2017,
    df_sat_2018,
    df_sat_2019
]

for dataset in dataset_raw:
    drop_pr_vi(dataset)

# %%
# Check for consistency on National 'state' rows across datasets

for dataset in dataset_raw:
    print((dataset['state'] == 'National').sum() + (dataset['state'] == 'national').sum())
# Out:
# 1
# 0
# 1
# 0
# 0
# 0

# %%
# Not every dataset has a national average; so drop

def drop_national(df_name):
    df_name.drop(
        df_name[
            (df_name['state'] == 'National') 
        ].index, inplace = True
    )

dataset_raw = [
    df_act_2017,
    df_act_2018,
    df_act_2019,
    df_sat_2017,
    df_sat_2018,
    df_sat_2019
]

for dataset in dataset_raw:
    drop_national(dataset)
    
for dataset in dataset_raw:
    print((dataset['state'] == 'National').sum() + (dataset['state'] == 'national').sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0

# %%
# only totals / composites useful;

df_act_2017.drop(['english', 'math', 'reading', 'science'], axis = 1, inplace = True)
df_sat_2017.drop(['ebrw', 'math'], axis = 1, inplace = True)
df_sat_2018.drop(['ebrw', 'math'], axis = 1, inplace = True)
df_sat_2019.drop(['ebrw', 'math'], axis = 1, inplace = True)

display(
    df_act_2017.head(0),
    df_sat_2017.head(0),
    df_sat_2018.head(0),
    df_sat_2019.head(0)
)
# Out:
# Empty DataFrame
# Columns: [state, participation_act_2017, total_act_2017]
# Index: []
# Empty DataFrame
# Columns: [state, participation_sat_2017, total_sat_2017]
# Index: []
# Empty DataFrame
# Columns: [state, participation_sat_2018, total_sat_2018]
# Index: []
# Empty DataFrame
# Columns: [state, participation_sat_2019, total_sat_2019]
# Index: []

# %% [markdown]
# **9. Merge dataframes that can be merged.**

# %%
df_merged = df_act_2017.merge(
    df_act_2018, how = "outer", on = "state"
).merge(
    df_act_2019, how = "outer", on = "state"
).merge(
    df_sat_2017, how = "outer", on = "state"
).merge(
    df_sat_2018, how = "outer", on = "state"
).merge(
    df_sat_2019, how = "outer", on = "state"
)

# %%
df_merged.head(21).T
# Out:
#                              0       1        2         3           4   \
# state                   Alabama  Alaska  Arizona  Arkansas  California
# participation_act_2017      1.0    0.65     0.62       1.0        0.31
# total_act_2017             19.2    19.8     19.7      19.4        22.8
# participation_act_2018      1.0    0.33     0.66       1.0        0.27
# total_act_2018             19.1    20.8     19.2      19.4        22.7
# participation_act_2019      1.0    0.38     0.73       1.0        0.23
# total_act_2019             18.9    20.1     19.0      19.3        22.6
# participation_sat_2017     0.05    0.38      0.3      0.03        0.53
# total_sat_2017             1165    1080     1116      1208        1055
# participation_sat_2018     0.06    0.43     0.29      0.05         0.6
# total_sat_2018             1166    1106     1149      1169        1076
# participation_sat_2019     0.07    0.41     0.31      0.06        0.63
# ...

# %%
# Perform any additional cleaning that you feel is necessary.
# DC state issue fixed in earlier section

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   52 non-null     string
#  1   participation_act_2017  52 non-null     float64
#  2   total_act_2017          52 non-null     float64
#  3   participation_act_2018  52 non-null     float64
#  4   total_act_2018          52 non-null     float64
#  5   participation_act_2019  52 non-null     float64
#  6   total_act_2019          52 non-null     float64
#  7   participation_sat_2017  52 non-null     float64
#  8   total_sat_2017          52 non-null     int64
#  9   participation_sat_2018  52 non-null     float64
#  10  total_sat_2018          52 non-null     int64
#  11  participation_sat_2019  52 non-null     float64
#  12  total_sat_2019          52 non-null     int64
# dtypes: float64(9), int64(3), string(1)
# memory usage: 5.7 KB

# %%
# Considering EDA to come, may make more sense to translate SAT totals into floats since they are state averages

df_merged['total_sat_2017'] = df_merged['total_sat_2017'].astype(float)
df_merged['total_sat_2018'] = df_merged['total_sat_2018'].astype(float)
df_merged['total_sat_2019'] = df_merged['total_sat_2019'].astype(float)

# %%
# Validating change
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   52 non-null     string
#  1   participation_act_2017  52 non-null     float64
#  2   total_act_2017          52 non-null     float64
#  3   participation_act_2018  52 non-null     float64
#  4   total_act_2018          52 non-null     float64
#  5   participation_act_2019  52 non-null     float64
#  6   total_act_2019          52 non-null     float64
#  7   participation_sat_2017  52 non-null     float64
#  8   total_sat_2017          52 non-null     float64
#  9   participation_sat_2018  52 non-null     float64
#  10  total_sat_2018          52 non-null     float64
#  11  participation_sat_2019  52 non-null     float64
#  12  total_sat_2019          52 non-null     float64
# dtypes: float64(12), string(1)
# memory usage: 5.7 KB

# %%
# check for duplicates
df_merged[df_merged.duplicated() == True]
# Out:
#     state  participation_act_2017  total_act_2017  participation_act_2018  \
# 20  Maine                    0.08            24.3                    0.07
#
#     total_act_2018  participation_act_2019  total_act_2019  \
# 20            24.0                    0.06            24.3
#
#     participation_sat_2017  total_sat_2017  participation_sat_2018  \
# 20                    0.95          1012.0                    0.99
#
#     total_sat_2018  participation_sat_2019  total_sat_2019
# 20          1013.0                    0.99          1013.0

# %%
# drop duplicate rows, then check output
df_merged.drop_duplicates(inplace = True);
df_merged.loc['19':'21']
# Out:
#        state  participation_act_2017  total_act_2017  participation_act_2018  \
# 19     Maine                    0.08            24.3                    0.07
# 21  Maryland                    0.28            23.6                    0.31
#
#     total_act_2018  participation_act_2019  total_act_2019  \
# 19            24.0                    0.06            24.3
# 21            22.5                    0.28            22.3
#
#     participation_sat_2017  total_sat_2017  participation_sat_2018  \
# 19                    0.95          1012.0                    0.99
# 21                    0.69          1060.0                    0.76
#
#     total_sat_2018  participation_sat_2019  total_sat_2019
# 19          1013.0                    0.99          1013.0
# 21          1080.0                    0.82          1058.0

# %%
# created cleaned df and set index
df_cleaned = df_merged.set_index(['state'])

# %%
# sort column names alphabetically
df_cleaned = df_cleaned.reindex(sorted(df_cleaned.columns), axis=1)

# %%
# Save your cleaned and merged dataframes as csv files.
df_merged.to_csv('./act_sat_scores_merged_by_state.csv')
df_cleaned.to_csv('./act_sat_scores_cleaned_by_state.csv')  # cleaned data includes change of index
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |No.|Feature|Type|Dataset|Description|Example|
# |:-:|:-:|:-:|:-:|:--|:--|
# |01|**state**|*string*|ACT/SAT|State names (count = 51; 50 U.S. states plus District of Columbia)|*e.g. Alabama*|
# |02|**participation_act_2017**|*float*|ACT|Participation rate for ACT 2017 by State (% as decimals)| *e.g. 1.0 = 100%*|
# |03|**participation_act_2018**|*float*|ACT|Participation rate for ACT 2018 by State (% as decimals)| *e.g. 1.0 = 100%*|
# |04|**participation_act_2019**|*float*|ACT|Participation rate for ACT 2019 by State (% as decimals)| *e.g. 1.0 = 100%*|
# |05|**participation_sat_2017**|*float*|SAT|Participation rate for SAT 2017 by State (% as decimals)| *e.g. 1.0 = 100%*|
# |06|**participation_sat_2018**|*float*|SAT|Participation rate for SAT 2018 by State (% as decimals)| *e.g. 1.0 = 100%*|
# |07|**participation_sat_2019**|*float*|SAT|Participation rate for SAT 2019 by State (% as decimals)| *e.g. 1.0 = 100%*|
# |08|**total_act_2017**|*float*|ACT|State averages for Composite (total) score for ACT 2017 by State (1 to 36)| *e.g. 20.2*|
# |09|**total_act_2018**|*float*|ACT|State averages for Composite (total) score for ACT 2018 by State (1 to 36)| *e.g. 20.2*|
# |10|**total_act_2019**|*float*|ACT|State averages for Composite (total) score for ACT 2019 by State (1 to 36)| *e.g. 20.2*|
# |11|**total_sat_2017**|*float*|SAT|State averages for Total score for SAT 2017 by State (400 to 1600)| *e.g. 1051*|
# |12|**total_sat_2018**|*float*|SAT|State averages for Total score for SAT 2018 by State (400 to 1600)| *e.g. 1051*|
# |13|**total_sat_2019**|*float*|SAT|State averages for Total score for SAT 2019 by State (400 to 1600)|*e.g. 1051*|
# |14|**participation_act_2017_to_2018**|*float*|ACT|Year-on-year change (% in decimals) from 2017 to 2018 for ACT participation|*e.g. +1% change is 0.01*|
# |15|**participation_act_2018_to_2019**|*float*|ACT|Year-on-year change (% in decimals) from 2018 to 2019 for ACT participation|*e.g. +1% change is 0.01*|
# |16|**participation_sat_2017_to_2018**|*float*|SAT|Year-on-year change (% in decimals) from 2017 to 2018 for SAT participation|*e.g. +1% change is 0.01*|
# |17|**participation_sat_2017_to_2018**|*float*|SAT|Year-on-year change (% in decimals) from 2018 to 2019 for SAT participation|*e.g. +1% change is 0.01*|
#
#
#
# <br>
#
# <i><font color = '#404040'>
#     <b>Note</b>: While it is not explicitly written in source material, we assume state averages are referring to state means. Also, added columns from EDA included in above table. This was done later in this notebook.
#     </font></i>

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. **Summary Statistics**

# %% [markdown]
# - Participation rates across years vary between just over 1% (0.02 in SAT minimums) to max of 100% (1.0).
# - Based on outside research, we already understand ACT and SAT scores should follow a normal distribution.
# - More summary statistics available in table below.

# %%
#Code:

# Summary statistics
df_cleaned.describe(include = 'all').T
# Out:
#                         count         mean        std     min       25%  \
# participation_act_2017   51.0     0.652549   0.321408    0.08     0.310
# participation_act_2018   51.0     0.617255   0.340371    0.07     0.285
# participation_act_2019   51.0     0.586667   0.345159    0.06     0.245
# participation_sat_2017   51.0     0.398039   0.352766    0.02     0.040
# participation_sat_2018   51.0     0.457451   0.373143    0.02     0.045
# participation_sat_2019   51.0     0.490588   0.387476    0.02     0.055
# total_act_2017           51.0    21.519608   2.020695   17.80    19.800
# total_act_2018           51.0    21.496078   2.111583   17.70    19.950
# total_act_2019           51.0    21.464706   2.194523   17.90    19.800
# total_sat_2017           51.0  1126.098039  92.494812  950.00  1055.500
# total_sat_2018           51.0  1120.019608  94.155083  977.00  1057.500
# total_sat_2019           51.0  1113.078431  97.197910  943.00  1038.000
#
# ...

# %% [markdown]
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# Dictionary comprehension

sd = {
    df_cleaned[col].name : 
    get_sd(df_cleaned[col]) 
    for col in df_cleaned
}

sd
# Out:
# {'participation_act_2017': 0.3182417575123181,
#  'participation_act_2018': 0.33701735820410317,
#  'participation_act_2019': 0.3417582373703047,
#  'participation_sat_2017': 0.3492907076664507,
#  'participation_sat_2018': 0.3694661922353942,
#  'participation_sat_2019': 0.3836584048685726,
#  'total_act_2017': 2.000786081581989,
#  'total_act_2018': 2.090779082141178,
#  'total_act_2019': 2.172901153595978,
#  'total_sat_2017': 91.58351056778743,
#  'total_sat_2018': 93.22742384464433,
#  'total_sat_2019': 96.24027185617864}

# %% [markdown]
# Note: the manually calculated function has a *ddof = 0* (delta degrees of freedom), which matches numpy default.
#
# The summary statistics, however, use a *ddof = 1*, and with a different divisor, the std is slightly different.

# %%
display(
    'From manual / numpy calculation, with ddof = 0:',
    np.std(df_cleaned['participation_act_2017'], ddof = 0),
    'From describe() / pandas calculation, with ddof = 1:',
    np.std(df_cleaned['participation_act_2017'], ddof = 1),
)
# Out:
# 'From manual / numpy calculation, with ddof = 0:'
# 0.3182417575123181
# 'From describe() / pandas calculation, with ddof = 1:'
# 0.32140842015886834

# %% [markdown]
# 3. **Investigate trends in the data.**
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# **Observation: States with 100% participation decreasing for ACT and increasing for SAT**
#
# We see, over time, while there were more states having 100% participation rates in the ACT initially, the number of states with 100% SAT participation rates grew from 4 to 8, while that of the ACT dropped from 17 to 15 over the same years.

# %%
# Looking for participation rates that are 100%
df_cleaned.mask(df_cleaned != 1).sum()[0:6]
# Out:
# participation_act_2017    17.0
# participation_act_2018    17.0
# participation_act_2019    15.0
# participation_sat_2017     4.0
# participation_sat_2018     5.0
# participation_sat_2019     8.0
# dtype: float64

# %% [markdown]
# Data below shows number of observations of states with 100% participation rates; this is likely to be state policy related. External qualitative research (via blog.prepscholar.com) indicates this to be the case, especially in the case of the ACT.
#
# This begs the question: **should the College Board target those states with high / 100% ACT participation, i.e. take a "conversion"-based strategy?**
#
# An alternative could be a state-wide campaign to boost overall interest in standardized testing as part of a strategy to **grow and capture the test-takers market**.
#
# We should also not forget to take a **defensive posture** for states that may swing towards the ACT as well.
#
# As part of simplifying assumptions, we assume that such defensive budgeting will be taken care of by a separate consulting team for the College Board as this requires detailed information on ACT Inc.'s strategy (the non-profit organization implementing ACT testing) which is out of scope of this project.
#
# We see that there are states where conversion strategy seems to have worked, e.g. in Colorado.

# %%
# Example of using boolean filtering (i.e., masking) to select a subset of the dataframe.
print('States with 100% participation rates in either ACT or SAT')
df_cleaned.mask(df_cleaned != 1, '-').head(10).T[0:6]  # head only
# Out:
# States with 100% participation rates in either ACT or SAT
# state                  Alabama Alaska Arizona Arkansas California Colorado  \
# participation_act_2017     1.0      -       -      1.0          -      1.0
# participation_act_2018     1.0      -       -      1.0          -        -
# participation_act_2019     1.0      -       -      1.0          -        -
# participation_sat_2017       -      -       -        -          -        -
# participation_sat_2018       -      -       -        -          -      1.0
# participation_sat_2019       -      -       -        -          -      1.0
#
# state                  Connecticut Delaware District of Columbia Florida
# participation_act_2017           -        -                    -       -
# participation_act_2018           -        -                    -       -
# participation_act_2019           -        -                    -       -
# participation_sat_2017         1.0      1.0                  1.0       -
# ...

# %% [markdown]
# To further examine where conversion has occurred, we now try observe where > 60% participation rates exist both in ACT and SAT per state. Such a filter should indicate where there has been some sort of state preference changes from the ACT to the SAT or vice versa.

# %%
# The query of "Do any states with 100% participation on a given test have a rate change year-to-year?"
# is somewhat included in the analysis above and below

print('States with >60% participation in at least one year for the ACT, and at least one year for the SAT')

df_cleaned[ 
    # columns to view
    ['participation_act_2017',
     'participation_act_2018',
     'participation_act_2019',
     'participation_sat_2017',
     'participation_sat_2018',
     'participation_sat_2019']
][ 
    # filters
    (
        (df_cleaned['participation_act_2017'] > 0.6)
        | (df_cleaned['participation_act_2018'] > 0.6) 
        | (df_cleaned['participation_act_2019'] > 0.6) 
    )
    & 
    (
        (df_cleaned['participation_sat_2017'] > 0.6)
        | (df_cleaned['participation_sat_2018'] > 0.6)
        | (df_cleaned['participation_sat_2019'] > 0.6)
    )
].head().T # transpose
# Out:
# States with >60% participation in at least one year for the ACT, and at least one year for the SAT
# state                   Colorado  Florida  Illinois  South Carolina  \
# participation_act_2017      1.00     0.73      0.93            1.00
# participation_act_2018      0.30     0.66      0.43            1.00
# participation_act_2019      0.27     0.54      0.35            0.78
# participation_sat_2017      0.11     0.83      0.09            0.50
# participation_sat_2018      1.00     0.56      0.99            0.55
# participation_sat_2019      1.00     1.00      1.00            0.68
#
# state                   West Virginia
# participation_act_2017           0.69
# participation_act_2018           0.65
# participation_act_2019           0.49
# participation_sat_2017           0.14
# participation_sat_2018           0.28
# participation_sat_2019           0.99

# %% [markdown]
# - From the above, we see that Colorado flipped from to SAT between 2017 and 2018 and remained with the SAT in 2019.
# - Florida and Illinois show a similar trend.
# - South Carolina shows signs of moving towards the SAT as well, and indeed no longer had 100% ACT participation in 2019 (dropped from 100% in 2017 and 2018).
# - West Virginia has also moved towards the SAT, although it never had 100% ACT participation rates either in 2017. As understood from external research, this state has a separate test outside the ACT and SAT as an alternative to either test.

# %% [markdown]
# <b>
#     Current state policies in relation to the SAT :
# </b><br>
#
# - In Colorado, Connecticut, Delaware, District of Columbia, and Idaho have free testing or the SAT school day;
# - In Illinois, Indiana, Michigan, New Hampshire, Rhode Island, the SAT is required;
# - In Minnesota, Ohio, Oklahoma, South Carolina, Tennessee, either ACT or SAT is required;
# - In West Virginia (must take SAT unless taking the West Virginia Alternative Summer Assessment.
# - The above has implications on College Board's targeting strategy.
#
#
# <i>Sources:</i>
# - https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice
# - https://blog.prepscholar.com/which-states-require-the-sat

# %% [markdown]
# With such **"conversion"** trends between tests, we should explore year-on-year changes in participation rates per test.

# %%
# Participation rate changes between years will be useful; add columns to df
# Formula: Change from Prev Year to Current Year = Current Year rate - Prev Year rate

# ACT
df_cleaned['participation_act_2017_to_2018'] = df_cleaned['participation_act_2018'] - df_cleaned['participation_act_2017']
df_cleaned['participation_act_2018_to_2019'] = df_cleaned['participation_act_2019'] - df_cleaned['participation_act_2018']

# SAT
df_cleaned['participation_sat_2017_to_2018'] = df_cleaned['participation_sat_2018'] - df_cleaned['participation_sat_2017']
df_cleaned['participation_sat_2018_to_2019'] = df_cleaned['participation_sat_2019'] - df_cleaned['participation_sat_2018']

# %%
df_cleaned.head().T[-4::]
# Out:
# state                           Alabama  Alaska  Arizona  Arkansas  California
# participation_act_2017_to_2018     0.00   -0.32     0.04      0.00       -0.04
# participation_act_2018_to_2019     0.00    0.05     0.07      0.00       -0.04
# participation_sat_2017_to_2018     0.01    0.05    -0.01      0.02        0.07
# participation_sat_2018_to_2019     0.01   -0.02     0.02      0.01        0.03

# %%
print('States with y-o-y participation rate changes more than +10% for the SAT')

df_cleaned[ 
    # columns to view
    ['participation_act_2017_to_2018',
     'participation_act_2018_to_2019',
     'participation_sat_2017_to_2018',
     'participation_sat_2018_to_2019']
][ 
    # filters
    (
        (df_cleaned['participation_sat_2017_to_2018'] >= 0.1)
        | (df_cleaned['participation_sat_2018_to_2019'] >= 0.1)
    )
].T # transpose
# Out:
# States with y-o-y participation rate changes more than +10% for the SAT
# state                           Colorado  Florida  Illinois  New Jersey  \
# participation_act_2017_to_2018     -0.70    -0.07     -0.50       -0.03
# participation_act_2018_to_2019     -0.03    -0.12     -0.08       -0.06
# participation_sat_2017_to_2018      0.89    -0.27      0.90        0.12
# participation_sat_2018_to_2019      0.00     0.44      0.01        0.00
#
# state                           New York  Oklahoma  Rhode Island  \
# participation_act_2017_to_2018     -0.04      0.00         -0.06
# participation_act_2018_to_2019     -0.05      0.00         -0.03
# participation_sat_2017_to_2018      0.12      0.01          0.26
# participation_sat_2018_to_2019      0.00      0.14          0.03
#
# state                           South Carolina  West Virginia
# participation_act_2017_to_2018            0.00          -0.04
# participation_act_2018_to_2019           -0.22          -0.16
# ...

# %% [markdown]
# The table above shows a few observations of how much changes have occurred between tests across states.

# %%
# Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
# Not much value in filtering for states with highest participation rates (=1.0)again; this was in previous analysis.
# Choose not to repeat that analysis.

display(
    'ACT Participation rate: Lowest 3 2017, 2018, 2019',
    df_cleaned['participation_act_2017'].nsmallest(3),
    df_cleaned['participation_act_2018'].nsmallest(3),
    df_cleaned['participation_act_2019'].nsmallest(3),
    'ACT Participation rate: Highest 3 2017, 2018, 2019',
    df_cleaned['participation_act_2017'].nlargest(3),
    df_cleaned['participation_act_2018'].nlargest(3),
    df_cleaned['participation_act_2019'].nlargest(3),
    'SAT Participation rate: Lowest 3 2017, 2018, 2019',
    df_cleaned['participation_sat_2017'].nsmallest(3),
    df_cleaned['participation_sat_2018'].nsmallest(3),
    df_cleaned['participation_sat_2019'].nsmallest(3),
    'SAT Participation rate: Highest 3 2017, 2018, 2019',
    df_cleaned['participation_sat_2017'].nlargest(3),
    df_cleaned['participation_sat_2018'].nlargest(3),
    df_cleaned['participation_sat_2019'].nlargest(3)
)
# Out:
# 'ACT Participation rate: Lowest 3 2017, 2018, 2019'
# state
# Maine            0.08
# Delaware         0.18
# New Hampshire    0.18
# Name: participation_act_2017, dtype: float64
# state
# Maine            0.07
# Rhode Island     0.15
# New Hampshire    0.16
# Name: participation_act_2018, dtype: float64
# state
# Maine           0.06
# Rhode Island    0.12
# Delaware        0.13
# Name: participation_act_2019, dtype: float64
# 'ACT Participation rate: Highest 3 2017, 2018, 2019'
# state
# Alabama     1.0
# Arkansas    1.0
# Colorado    1.0
# Name: participation_act_2017, dtype: float64
# state
# Alabama     1.0
# Arkansas    1.0
# Kentucky    1.0
# Name: participation_act_2018, dtype: float64
# state
# Alabama     1.0
# Arkansas    1.0
# Kentucky    1.0
# Name: participation_act_2019, dtype: float64
# 'SAT Participation rate: Lowest 3 2017, 2018, 2019'
# state
# Iowa            0.02
# Mississippi     0.02
# North Dakota    0.02
# Name: participation_sat_2017, dtype: float64
# state
# ...

# %%
# Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?

display(
    'ACT total/composite score: Lowest 3 2017, 2018, 2019',
    df_cleaned['total_act_2017'].nsmallest(3),
    df_cleaned['total_act_2018'].nsmallest(3),
    df_cleaned['total_act_2019'].nsmallest(3),
    'ACT total/composite score: Highest 3 2017, 2018, 2019',
    df_cleaned['total_act_2017'].nlargest(3),
    df_cleaned['total_act_2018'].nlargest(3),
    df_cleaned['total_act_2019'].nlargest(3),
    'SAT total/composite score: Lowest 3 2017, 2018, 2019',
    df_cleaned['total_sat_2017'].nsmallest(3),
    df_cleaned['total_sat_2018'].nsmallest(3),
    df_cleaned['total_sat_2019'].nsmallest(3),
    'SAT total/composite score: Highest 3 2017, 2018, 2019',
    df_cleaned['total_sat_2017'].nlargest(3),
    df_cleaned['total_sat_2018'].nlargest(3),
    df_cleaned['total_sat_2019'].nlargest(3)
)
# Out:
# 'ACT total/composite score: Lowest 3 2017, 2018, 2019'
# state
# Nevada            17.8
# Mississippi       18.6
# South Carolina    18.7
# Name: total_act_2017, dtype: float64
# state
# Nevada            17.7
# South Carolina    18.3
# Mississippi       18.6
# Name: total_act_2018, dtype: float64
# state
# Nevada         17.9
# Mississippi    18.4
# Louisiana      18.8
# Name: total_act_2019, dtype: float64
# 'ACT total/composite score: Highest 3 2017, 2018, 2019'
# state
# New Hampshire    25.5
# Massachusetts    25.4
# Connecticut      25.2
# Name: total_act_2017, dtype: float64
# state
# Connecticut      25.6
# Massachusetts    25.5
# New Hampshire    25.1
# Name: total_act_2018, dtype: float64
# state
# Connecticut      25.5
# Massachusetts    25.5
# New Hampshire    25.0
# Name: total_act_2019, dtype: float64
# 'SAT total/composite score: Lowest 3 2017, 2018, 2019'
# state
# District of Columbia     950.0
# Delaware                 996.0
# Idaho                   1005.0
# ...

# %%
# Do any states have >50% participation on both tests each year?
# filter and reset view to show rows grouped by test scores

print('States with >50% participation on both tests each year')

df_cleaned[ 
    # columns to view
    ['participation_act_2017',
     'participation_sat_2017',
     'participation_sat_2018',     
     'participation_act_2018',
     'participation_act_2019',
     'participation_sat_2019']
][ 
    # filters
    (
        (df_cleaned['participation_act_2017'] > 0.5)
        & (df_cleaned['participation_sat_2017'] > 0.5)
    )
    |
    (
        (df_cleaned['participation_act_2018'] > 0.5) 
        & (df_cleaned['participation_sat_2018'] > 0.5)
    )
    |
    (
        (df_cleaned['participation_act_2019'] > 0.5) 
        & (df_cleaned['participation_sat_2019'] > 0.6) 
    )
].head().T # transpose
# Out:
# States with >50% participation on both tests each year
# state                   Florida  Georgia  Hawaii  North Carolina  \
# participation_act_2017     0.73     0.55    0.90            1.00
# participation_sat_2017     0.83     0.61    0.55            0.49
# participation_sat_2018     0.56     0.70    0.56            0.52
# participation_act_2018     0.66     0.53    0.89            1.00
# participation_act_2019     0.54     0.49    0.80            1.00
# participation_sat_2019     1.00     0.71    0.54            0.51
#
# state                   South Carolina
# participation_act_2017            1.00
# participation_sat_2017            0.50
# participation_sat_2018            0.55
# participation_act_2018            1.00
# participation_act_2019            0.78
# participation_sat_2019            0.68

# %%
# (Example of sorting your dataframe by a column)
# Targeting states that favour SAT and still have test-takers not taking either SAT or ACT, 
# i.e. ACT + SAT participation < 100% (take 90%), and favours SAT (SAT participation > 50%)
df_cleaned[
    (df_cleaned['participation_sat_2019'] + df_cleaned['participation_act_2019'] < 0.9)
    & (df_cleaned['participation_sat_2019'] > 0.5)
].sort_values('participation_act_2019').head().T[0:6]
# Out:
# state                   Pennsylvania  Vermont  Virginia  California
# participation_act_2017          0.23     0.29      0.29        0.31
# participation_act_2018          0.20     0.24      0.24        0.27
# participation_act_2019          0.17     0.20      0.21        0.23
# participation_sat_2017          0.65     0.60      0.65        0.53
# participation_sat_2018          0.70     0.64      0.68        0.60
# participation_sat_2019          0.70     0.66      0.68        0.63

# %% [markdown]
# Pennsylvania, Vermont, Virgina and California have less than 90% of 2019 potential test-takers taking either ACT of SAT, and also have more than 50% of 2019 test-takers already taking the SAT.
#
# These are potentially states that have test-takers to capture as part of a **growth** strategy.
#
# We note that this may also be a sign that standardized tests in general are less popular, which is likely the case for California, so qualitatively we should filter out such states.
#
# Nonetheless, **Pennsylvania, Vermont and Virginia look like promising targets for College Board to refocus efforts and grow SAT participation rates**.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---

# %% [markdown]
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#     Have a title
#     Have axis labels
#     Have appropriate tick labels
#     Text is legible in a plot
#     Plots demonstrate meaningful and valid relationships
#     Have an interpretation to aid understanding

plt.figure(figsize = (16,10))
plt.title('Correlation matrix for ACT / SAT:\nParticipation rates, Total scores across years\n(using sns.heatmap)',
          fontweight = 'bold')
sns.heatmap(df_cleaned.corr(), annot=True, cmap = 'RdBu', mask = np.triu(df_cleaned.corr()))
plt.tight_layout();

plt.savefig('./sns_heatmap_all.png')

# %% [markdown]
# The heatmap above shows correlations between different column variables. Strong positive correlation is represented by darker shades of blue, weaker correlations tending towards zero fade to whie, and stronger negative correlation is reflected in darker shades of red.
#
# **Findings**
# - Obvious red clusters (strong negative correlation) are visible in:
#   1. ACT vs SAT participation rates (signalling test-takers are unlikely to take both tests) as well as
#   2. ACT / SAT participation rates against their respective total scores (meaning the higher the participation, the lower the state averages).
#   <br><br>
# - The latter red cluster (higher participation correlated with lower scores) may imply that there can be experiments to do around campaign marketing since test-takers tend to score more poorly on average in states with high participation.
#   <br><br>
# - Orange cluster, i.e. some negative correlation, in:
#   1. Total SAT scores per year vs Total ACT scores for the same year
#   <br><br>
# - Blue clusters (positive correlation) also exist in:
#   1. Total SAT scores per year vs ACT participation rates
#   2. Total ACT scores per year vs SAT participations rates
#   3. Total ACT scores in one year vs ACT scores in other years
#   4. Total SAT scores in one year vs SAT scores in other years
#   5. Total ACT participation in one year vs ACT participation in other years (0.9 to 0.99)
#   6. Total SAT participation in one year vs SAT participation in other years (0.84 to 0.95)
#   <br><br>
# - For blue clusters (1) and (2), the correlation is a lighter blue (some positive correlation). This seems to make some sense since we have seen strong negative correlation early on in the red cluster (2), but the reasons are not intuitive.
#   <br><br>
# - For blue clusters (3) and (4), the strong postive correlations indicate that states generally do not change their standardized test performances drastically across years. This is interesting because it may mean that score averages per state are 'sticky'. The following two line plots illustrate this further.
#   <br><br>
# - For blue clusters (5) and (6), the strong postive correlations (dark blue) hint at the "stickiness" of state participation per test, i.e. whether between years high participation will remain high and low participation will remain low. In both ACT and SAT, the correlation seems to be getting stronger towards 2019, although naturally there must be some time series autocorrelation.

# %% [markdown]
# <a name = 'line_plots'>**Line plots**

# %%
plt.figure(figsize=(16,5))
plt.title('ACT score state averages across years')
plt.plot(df_cleaned['total_act_2017'], color = 'grey', label = 'ACT 2017 state averages', linestyle = 'dotted')
plt.plot(df_cleaned['total_act_2018'], color = 'orange', label = 'ACT 2018 state averages', linestyle = 'dashed')
plt.plot(df_cleaned['total_act_2019'], color = 'red', label = 'ACT 2019 state averages')
plt.legend()
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.ylabel('ACT composite scores; max range 1-36')
plt.tight_layout();

plt.savefig('./lineplot_ACT_scores.png')

# %%
plt.figure(figsize=(16,5))
plt.title('SAT score state averages across years')
plt.plot(df_cleaned['total_sat_2017'], color = 'grey', label = 'SAT 2017 state averages', linestyle = 'dotted')
plt.plot(df_cleaned['total_sat_2018'], color = 'royalblue', label = 'SAT 2018 state averages', linestyle = 'dashed')
plt.plot(df_cleaned['total_sat_2019'], color = 'navy', label = 'SAT 2019 state averages')
plt.legend()
plt.xlabel('States')
plt.xticks(rotation = 90)
plt.ylabel('SAT total scores; max range 400-1600')
plt.tight_layout();

plt.savefig('./lineplot_SAT_scores.png')

# %% [markdown]
# The lineplots above illustrate how state averages are highly correlated between years for most states. Notably, where there are swings between years (i.e. less overlap in lines and less correlation across years) like in Colorado, Florida, and Illinois, there were also changes in state policy relating to standardized tests, mostly relating to state contracts with College Board or SAT School Day.

# %% [markdown]
# **Histogram subplots**
#
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
plt.figure(figsize = (16,8))
plt.suptitle('Participation rates, ACT: 2017, 2018, 2019 (left to right)\n x-axis: participation % (0.0 to 1.0) \n y-axis: state count',
            size = 16)

plt.subplot(2,3,1)
plt.hist(df_cleaned['participation_act_2017'],15, color = 'grey')

plt.subplot(2,3,2)
plt.hist(df_cleaned['participation_act_2018'],15, color = 'orange')

plt.subplot(2,3,3)
plt.hist(df_cleaned['participation_act_2019'],15, color = 'red')

plt.tight_layout();

plt.savefig('./hist_subplot_participation_ACT.png')

# %% [markdown]
# <font size = '2'><center><i> ACT subplots across years show clustering towards 100% participation (1.0),
#     indicative of how state policies still generally favour the ACT as a standardized test. </i></center></font>

# %%
plt.figure(figsize = (16,8))
plt.suptitle('Participation rates, SAT: 2017, 2018, 2019 (left to right)\n x-axis: participation % (0.0 to 1.0) \n y-axis: state count',
            size = 16)

plt.subplot(2,3,1)
plt.hist(df_cleaned['participation_sat_2017'],15, color = 'grey')

plt.subplot(2,3,2)
plt.hist(df_cleaned['participation_sat_2018'],15, color = 'royalblue')

plt.subplot(2,3,3)
plt.hist(df_cleaned['participation_sat_2019'],15, color = 'navy')

plt.tight_layout();

plt.savefig('./hist_subplot_participation_SAT.png')

# %% [markdown]
# <font size = '2'><center><i>SAT subplots across years show clustering towards 0% participation (0.0), indicative of how state policies still generally do not favour the SAT as a standardized test.</i></center></font>

# %% [markdown]
# **Boxplots**
#
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels

# %%
fig = plt.figure(figsize = (16,5))

plt.title('Participation Rates (0.0 to 1.0)\n(ACT / SAT; 2017 to 2019)', weight = 'bold', size = 16)

df_cleaned[df_cleaned.columns[0:6]].boxplot(
    grid = False, 
    showmeans = True)

plt.tight_layout()

plt.savefig('./boxplot_participation.png')

# %% [markdown]
# Means per boxplot are shown at the respective green triangle, with the green line denoting the median.
# Wherein the triangle is below the line, that means that the median is above the mean, implying the distribution is skewed to the left. The converse is true.
#
# The skewness in ACT participation rates were towards the left (as seen in the histogram plot as well), although notably in 2019 it became slightly skewed to the right (also known as positive skew).
#
# For SAT participation rates, 2017 saw some skewness to the right (mean above median), and then skewness to the left (median above mean) in later years.

# %%
fig = plt.figure(figsize = (16,5))

plt.title('ACT state averages (Max range: 1 to 36)\n(Total state count = 51; 2017 to 2019)',
          weight = 'bold', size = 16)

df_cleaned[df_cleaned.columns[6:9]].boxplot(
    figsize = (16,3),
    grid = True,
    vert = False,
    showmeans = True)

plt.tight_layout()

# %%
fig = plt.figure(figsize = (16,5))
plt.title('SAT state averages (Max range: 400 to 1600)\n(Total state count = 51; 2017 to 2019)', 
          weight = 'bold', size = 16)

df_cleaned[df_cleaned.columns[9:12]].boxplot(
    figsize = (16,3), 
    grid = True, 
    vert = False,
    showmeans = True)

plt.tight_layout()

# %% [markdown]
# We split the boxplots for ACTs and SATs as there are different scoring ranges.
#
# Skewness is similarly visible by the comparison of the position of the green triangle (mean) against the green median line. Where the median is below the mean (i.e. the triangle is to the right of the line), the distribution is right-skewed.

# %% [markdown]
# **Scatter plots**
#
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable

# %%
# custom function for drawing scatterplot
def scatterplot(df, col1, col2, title, marker_type = 'x', c_face=None, c_edge=None):
    sns.regplot(df[col1],
                df[col2],
                scatter_kws={
                    'facecolors' : c_face,
                    'edgecolor' : c_edge},
                marker = marker_type,
                line_kws = {
                    'color' : '#404040'}
               )
    plt.title(title,fontsize=14)
    plt.xlabel(col1,fontsize=12)
    plt.ylabel(col2,fontsize=12)

# %%
plt.figure(figsize=(16,5))

# Scatterplot: SAT vs ACT (2017)
plt.subplot(1,3,1)
scatterplot(df_cleaned,
            'participation_act_2017',
            'participation_sat_2017',
            'ACT vs SAT participation rate (2017)',
            marker_type = 'o',
            c_face = 'grey',
            c_edge = 'black')
# Scatterplot: SAT vs ACT (2018)
plt.subplot(1,3,2)
scatterplot(df_cleaned,
            'participation_act_2018',
            'participation_sat_2018',
            'ACT vs SAT participation rate (2018)',
            marker_type = '+',
            c_face = 'royalblue')
# Scatterplot: SAT vs ACT (2019)
plt.subplot(1,3,3)
scatterplot(df_cleaned,
            'participation_act_2019',
            'participation_sat_2019',
            'ACT vs SAT participation rate (2019)',
            c_face = 'navy')

plt.tight_layout();

plt.savefig('./scatterplot_participation_ACT_vs_SAT_years.png')
# Out:
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,11))

# Scatterplot: ACT participation (2017 vs 2018)
plt.subplot(2,2,1)
scatterplot(df_cleaned,
            'participation_act_2017',
            'participation_act_2018',
            'ACT participation rate (2017 vs 2018)',
            marker_type = 'o',
            c_face = 'grey',
            c_edge = 'black')
# Scatterplot: ACT participation (2018 vs 2019)
plt.subplot(2,2,2)
scatterplot(df_cleaned,
            'participation_act_2018',
            'participation_act_2019',
            'ACT participation rate (2018 vs 2019)',
            marker_type = 'x',
            c_face = 'red')
# Scatterplot: SAT participation 2017 vs 2018)
plt.subplot(2,2,3)
scatterplot(df_cleaned,
            'participation_sat_2017',
            'participation_sat_2018',
            'SAT participation rate (2017 vs 2018)',
            marker_type = 'o',
            c_face = 'grey',
            c_edge = 'black')
# Scatterplot: SAT vs ACT (2019)
plt.subplot(2,2,4)
scatterplot(df_cleaned,
            'participation_sat_2018',
            'participation_sat_2019',
            'SAT participation rate (2018 vs 2019)',
            marker_type = 'x',
            c_face = 'navy')

plt.tight_layout();

plt.savefig('./scatterplot_participation_ACT_SAT_betweeen_years.png')
# Out:
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# We see negative correlation between ACT and SAT participation rates; there is a natural limit as most people would not take both tests on their own accord (one would suffice even if there is such a college admissions requirement).
#
# Between years, there is a positive correlation. Notably, there are a number of outliers which we can investigate further as part of next phase deep dives. These outliers should be taken seriously as they may show deeper issues with the population especially in the case where SAT participation rates are seen to be falling over the years. Notably, the SAT participation rate outlier between 2017 and 2018 did not seem to recur in the 2018 to 2019, which is comforting.

# %%
plt.figure(figsize=(16,5))

# Scatterplot: ACT participation vs scores (2017)
plt.subplot(1,3,1)
scatterplot(df_cleaned,
            'participation_act_2017',
            'total_act_2017',
            'ACT participation vs scores (2017)',
            marker_type = 'o',
            c_face = 'grey',
            c_edge = 'black')
# Scatterplot: ACT participation vs scores (2018)
plt.subplot(1,3,2)
scatterplot(df_cleaned,
            'participation_act_2018',
            'total_act_2018',
            'ACT participation vs scores (2018)',
            marker_type = '+',
            c_face = 'orange')
# Scatterplot: ACT participation vs scores (2019)
plt.subplot(1,3,3)
scatterplot(df_cleaned,
            'participation_act_2019',
            'total_act_2019',
            'ACT participation vs scores  (2019)',
            c_face = 'red')

plt.tight_layout();

plt.savefig('./scatterplot_ACT_part_vs_scores_overyears.png')
# Out:
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(16,5))

# Scatterplot: SAT participation vs scores (2017)
plt.subplot(1,3,1)
scatterplot(df_cleaned,
            'participation_sat_2017',
            'total_sat_2017',
            'SAT participation vs scores (2017)',
            marker_type = 'o',
            c_face = 'grey',
            c_edge = 'black')
# Scatterplot: SAT participation vs scores (2018)
plt.subplot(1,3,2)
scatterplot(df_cleaned,
            'participation_sat_2018',
            'total_sat_2018',
            'SAT participation vs scores (2018)',
            marker_type = '+',
            c_face = 'royalblue')
# Scatterplot: SAT participation vs scores (2019)
plt.subplot(1,3,3)
scatterplot(df_cleaned,
            'participation_sat_2019',
            'total_sat_2019',
            'SAT participation vs scores  (2019)',
            c_face = 'navy')

plt.tight_layout();

plt.savefig('./scatterplot_SAT_part_vs_scores_overyears.png')
# Out:
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\YX\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Additional plots**
#
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.
#
# [Link to line plot segment](#line_plots)

# %%
# review via link to line plots which are after heatmap section

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# <font color = '#808080'>
#     Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here. </font>

# %% [markdown]
# Key insights are:
# 1. States where the ACT is mandatory have, in recent years, been influenced to take up the SAT.
# 2. Where there is already a "default" test, state participation towards that test tends to be quite sticky.
# 3. Pennsylvania, Vermont, and Virgina seem to be promising targets for College Board to double up efforts to grow participation rates. We see them as "low hanging fruit" since 10% of 2019 potential test-takers did not take either the ACT or the SAT, and there are over 50% of 2019 test-takers already favouring the SAT. Peer group targeting may make for a good campaign strategy here.
#
# On top of this, the College Board should take care to make more deep dives to defend its existing market share. While there are more states now appearing to favour SATs (e.g. Colorado), the College Board must continue to maintain efforts to lobby state support so participation rates in those states are maintained.
#
# Where there was direct capture of state support towards the SAT in states, best practices should be generated so similar efforts can be used to target other states which currently favour the ACT (15 still at 100% participation in 2019).
#
# Also, the College Board would do well to manage concerns about the progressiveness of standardized tests. Various news sources have reported that colleges are starting to drop standardized testing requirements for admissions. This is one of the reasons why California was not proposed as a state to be targeted even though it does fit into a similar category as Pennsylvaina, Vermont and Virginia based on existing participation rate trends.

# %% [markdown]
# <font color = '#808080'>
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
# </font>
